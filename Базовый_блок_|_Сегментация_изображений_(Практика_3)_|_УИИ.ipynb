# %% [markdown]
# <a href="https://colab.research.google.com/github/kuzovkov/neural-university/blob/main/%D0%91%D0%B0%D0%B7%D0%BE%D0%B2%D1%8B%D0%B9_%D0%B1%D0%BB%D0%BE%D0%BA_%7C_%D0%A1%D0%B5%D0%B3%D0%BC%D0%B5%D0%BD%D1%82%D0%B0%D1%86%D0%B8%D1%8F_%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B9_(%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_3)_%7C_%D0%A3%D0%98%D0%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Содержание темы**
#
# 1. [Теория](https://colab.research.google.com/drive/1188DQBNnxXgxxZoldO8cXiQFYaO9PoOh?usp=sharing)
#
# 2. [Практический ноутбук 1](https://colab.research.google.com/drive/1EcHhwOCIhvm4mpxEbDGRawIJ4BpbAyqO?usp=sharing)
#
# 3. [Практический ноутбук 2](https://colab.research.google.com/drive/1pHONL5J4AVraE-SYJnpes7KdicPsD9qt?usp=sharing)
#
# 3. Практический ноутбук 3

# %% [markdown]
# В финальном ноутбуке занятия мы создадим сегментриующую модель на базе изображений самолетов. Эта задача значительно проще предыдущей, поскольку на оригинальном изображении будет всего два класса объектов:
# - самолет
# - фон

# %% [markdown]
# ## Подключение бибилиотек

# %%
# Основа для модели нейронной сети
from tensorflow.keras.models import Model

# Стандартные слои keras
from tensorflow.keras.layers import Input, Conv2DTranspose, concatenate, Activation, MaxPooling2D, Conv2D, BatchNormalization

# Оптимизатор Adam
from tensorflow.keras.optimizers import Adam

# Дополнительные утилиты keras
from tensorflow.keras import utils

# Инструменты для построения графиков
import matplotlib.pyplot as plt

# Инструменты для работы с изображениями
from tensorflow.keras.preprocessing import image

# Инструменты для работы с массивами
import numpy as np

# Системные инструменты
import time, random, gdown, os

# Дополнительные инструменты для работы с изображениями
from PIL import Image

# Дополнительные инструменты визуализации
import seaborn as sns
sns.set_style('darkgrid')

# %% [markdown]
# ## Загрузка датасета

# %% [markdown]
# По аналогии с базой "Стройка" подготовим необходимые данные для обучения сети для базы "Самолеты"

# %%
# Загрузка датасета из облака

gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l14/airplane_456x256.zip', None, quiet=True)
#gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l14/airplane_912x512.zip', None, quiet=True)
#gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l14/airplane_1920x1080.zip', None, quiet=True)
# Out:
# 'airplane_456x256.zip'

# %%
# Распаковка архива

# !unzip -qo airplane_456x256.zip

# %% [markdown]
# Для данного занятия возьмем уменьшенный размер изображений (**456x256** пикселей). При наличии достаточных вычислительных мощностей вы можете воспользоваться базой с бОльшим разрешением.

# %%
# Глобальные параметры

IMG_WIDTH = 256               # Ширина картинки
IMG_HEIGHT = 456              # Высота картинки
CLASS_COUNT = 2               # Количество классов на изображении
TRAIN_DIRECTORY = 'train'     # Название папки с файлами обучающей выборки
VAL_DIRECTORY = 'val'         # Название папки с файлами проверочной выборки

# %%
# Служебная функция загрузки выборки изображений из файлов в папке

def load_imageset(folder,   # имя папки
                  subset,   # подмножество изображений - оригинальные или сегментированные
                  title     # имя выборки
                  ):

    # Cписок для хранения изображений выборки
    image_list = []

    # Отметка текущего времени
    cur_time = time.time()

    # Для всех файлов в каталоге по указанному пути:
    for filename in sorted(os.listdir(f'{folder}/{subset}')):

        # Чтение очередной картинки и добавление ее в список изображений требуемого размера
        image_list.append(image.load_img(os.path.join(f'{folder}/{subset}', filename),
                                         target_size=(IMG_WIDTH, IMG_HEIGHT)))

    # Вывод времени загрузки картинок выборки
    print('{} выборка загружена. Время загрузки: {:.2f} с'.format(title,
                                                                  time.time() - cur_time))

    # Вывод количества элементов в выборке
    print('Количество изображений:', len(image_list))

    return image_list

# %%
# Функция для просмотра изображений из набора

def show_imageset(image_list,  # выборка изображений
                  n            # количество картинок для просмотра
                  ):

    fig, axs = plt.subplots(1, n, figsize=(25, 10))       # Создание полотна из n графиков

    # Вывод в цикле n случайных изображений
    for i in range(n):
        img = random.choice(image_list)                   # Выборка случайного фото для отображения
        axs[i].axis('off')
        axs[i].imshow(img)                                # Отображение картинки

    plt.show()                                            # Отрисовка изображений

# %%
# Загрузка входных изображений

train_images = load_imageset(TRAIN_DIRECTORY, 'original', 'Обучающая')
val_images = load_imageset(VAL_DIRECTORY, 'original', 'Проверочная')
# Out:
# Обучающая выборка загружена. Время загрузки: 0.29 с
# Количество изображений: 931
# Проверочная выборка загружена. Время загрузки: 0.01 с
# Количество изображений: 50

# %%
# Просмотр входных изображений из обучающего набора

show_imageset(train_images, 5)

# %%
# Загрузка выходных (сегментированных) изображений

train_segments = load_imageset(TRAIN_DIRECTORY, 'segment', 'Обучающая')
val_segments = load_imageset(VAL_DIRECTORY, 'segment', 'Проверочная')
# Out:
# Обучающая выборка загружена. Время загрузки: 0.24 с
# Количество изображений: 931
# Проверочная выборка загружена. Время загрузки: 0.01 с
# Количество изображений: 50

# %%
# Просмотр сегментированных изображений из обучающего набора

show_imageset(train_segments, 5)

# %%
# Цвета пикселов сегментированных изображений

AIRPLANE = (255, 255, 255)      # Самолет (белый)
BACKGROUND = (0, 0, 0)          # Фон (черный)

# %%
CLASS_LABELS = (AIRPLANE, BACKGROUND)

# %% [markdown]
# ## Создание выборки

# %% [markdown]
# Переведем сегментированные изображения в одноканальные сегментированные с номером класса в каждом пикселе (функции из практики №1):

# %%
# Функция преобразования цветного сегментированного изображения в метки классов

def rgb_to_labels(image_list  # список цветных изображений
                 ):

    result = []

    # Для всех картинок в списке:
    for d in image_list:
        sample = np.array(d)
        # Создание пустой 1-канальной картики
        y = np.zeros((IMG_WIDTH, IMG_HEIGHT, 1), dtype='uint8')

        # По всем классам:
        for i, cl in enumerate(CLASS_LABELS):
            # Нахождение 3-х канальных пикселей классов и занесение метки класса
            y[np.where(np.all(sample == CLASS_LABELS[i], axis=-1))] = i

        result.append(y)

    return np.array(result)

# %% [markdown]
# Обратная функция, перевод одноканальных сегментированных изображений с номером класса в каждом пикселе в 3х канальное RGB сегментированное изображение:

# %%
# Функция преобразования тензора меток класса в цветное сегметрированное изображение

def labels_to_rgb(image_list  # список одноканальных изображений
                 ):

    result = []

    # Для всех картинок в списке:
    for y in image_list:
        # Создание пустой цветной картики
        temp = np.zeros((IMG_WIDTH, IMG_HEIGHT, 3), dtype='uint8')

        # По всем классам:
        for i, cl in enumerate(CLASS_LABELS):
            # Нахождение пикселов класса и заполнение цветом из CLASS_LABELS[i]
            temp[np.where(np.all(y==i, axis=-1))] = CLASS_LABELS[i]

        result.append(temp)

    return np.array(result)

# %% [markdown]
# Сформируем выборки:

# %%
# Формирование обучающей выборки

x_train = []                          # Cписок под обучающую выборку

for img in train_images:              # Для всех изображений выборки:
    x = image.img_to_array(img)       # Перевод изображения в numpy-массив формы: высота x ширина x количество каналов
    x_train.append(x)                 # Добавление элемента в x_train

x_train = np.array(x_train)           # Перевод всей выборки в numpy
print(x_train.shape)                  # Форма x_train
# Out:
# (931, 256, 456, 3)

# %%
# Формирование проверочной выборки

x_val = []                            # Cписок под проверочную выборку

for img in val_images:                # Для всех изображений выборки:
    x = image.img_to_array(img)       # Перевод изображения в numpy-массив формы: высота x ширина x количество каналов
    x_val.append(x)                   # Добавление элемента в x_train

x_val = np.array(x_val)               # Перевод всей выборки в numpy
print(x_val.shape)                    # Форма x_train
# Out:
# (50, 256, 456, 3)

# %%
# Преобразование сегментов в метки классов

y_train = rgb_to_labels(train_segments)
y_val = rgb_to_labels(val_segments)

print(y_train.shape)
print(y_val.shape)
# Out:
# (931, 256, 456, 1)
# (50, 256, 456, 1)

# %% [markdown]
# ## Простая линейная (последовательная) архитектура

# %% [markdown]
# Для начала попробуем простую линейную модель:

# %%
def sequential_segmentation_net(class_count,  # количество классов
                                input_shape   # форма входного изображения
                                ):

    img_input = Input(input_shape)                                              # Создаем входной слой формой input_shape
    x = Conv2D(128, (3, 3), padding='same', name='block1_conv1')(img_input)     # Добавляем Conv2D-слой с 128-нейронами
    x = BatchNormalization()(x)                                                 # Добавляем слой BatchNormalization
    x = Activation('relu')(x)

    x = Conv2D(64, (3, 3), padding='same', name='block1_conv3')(x)              # Добавляем Conv2D-слой с 128-нейронами
    x = BatchNormalization()(x)                                                 # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                                   # Добавляем слой Activation

    x = Conv2D(32, (3, 3), padding='same', name='block1_conv4')(x)              # Добавляем Conv2D-слой с 128-нейронами
    x = BatchNormalization()(x)                                                 # Добавляем слой BatchNormalization
    x = Activation('relu')(x)

    x = Conv2D(16, (3, 3), padding='same', name='block1_conv5')(x)              # Добавляем Conv2D-слой с 128-нейронами
    x = BatchNormalization()(x)                                                 # Добавляем слой BatchNormalization
    x = Activation('relu')(x)

    x = Conv2D(class_count, (3, 3), activation='softmax', padding='same')(x)    # Добавляем Conv2D-Слой с softmax-активацией на class_count-нейронов

    model = Model(img_input, x)                                                 # Создаем модель с входом 'img_input' и выходом 'x'

    # Компилируем модель
    model.compile(optimizer=Adam(learning_rate=1e-4),
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])

    # Возвращаем сформированную модель
    return model

# %%
# Создание модели и вывод сводки по архитектуре

model_seq = sequential_segmentation_net(CLASS_COUNT,
                                       (IMG_WIDTH, IMG_HEIGHT, 3))

model_seq.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 256, 456, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 256, 456, 128)  │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 256, 456, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 256, 456, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv3 (Conv2D)           │ (None, 256, 456, 64)   │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 256, 456, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 256, 456, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv4 (Conv2D)           │ (None, 256, 456, 32)   │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 256, 456, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 256, 456, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv5 (Conv2D)           │ (None, 256, 456, 16)   │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 256, 456, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 256, 456, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 256, 456, 2)    │           290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,714 (397.32 KB)
#  Trainable params: 101,234 (395.45 KB)
#  Non-trainable params: 480 (1.88 KB)

# %%
# Обучение модели

history = model_seq.fit(x_train, y_train,
                        epochs=50, batch_size=16,
                        validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 63s 571ms/step - loss: 0.3636 - sparse_categorical_accuracy: 0.8813 - val_loss: 0.6081 - val_sparse_categorical_accuracy: 0.6804
# Epoch 2/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 39s 343ms/step - loss: 0.2043 - sparse_categorical_accuracy: 0.9416 - val_loss: 0.5038 - val_sparse_categorical_accuracy: 0.6979
# Epoch 3/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 352ms/step - loss: 0.1603 - sparse_categorical_accuracy: 0.9524 - val_loss: 0.2086 - val_sparse_categorical_accuracy: 0.9333
# Epoch 4/50
# 38/59 ━━━━━━━━━━━━━━━━━━━━ 7s 339ms/step - loss: 0.1364 - sparse_categorical_accuracy: 0.9564

# %%
# Отображение графиков обучения модели

plt.figure(figsize=(14, 7))
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.show()

# %% [markdown]
# Мы получили довольно неплохие результаты. **0.97** - очень хороший показатель для проверочной выборки.
#
# Теперь взглянем на результат работы нашей модели:

# %%
# Функция визуализации процесса сегментации изображений, модифицированная для вывода по списку индексов

def process_images(model,                       # обученная модель
                   count=1,                     # количество случайных картинок для сегментации
                   indexes=None,                # список индексов изображений в проверочной выборке
                   ):

    if indexes is None:
        # Генерация случайного списка индексов в количестве count между (0, len(x_val)
        indexes = np.random.randint(0, len(x_val), count)
    else:
        count = len(indexes)

    # Вычисление предсказания сети для картинок с отобранными индексами
    predict = np.argmax(model.predict(x_val[indexes]), axis=-1)

    # Подготовка цветов классов для отрисовки предсказания
    orig = labels_to_rgb(predict[..., None])
    fig, axs = plt.subplots(3, count, figsize=(25, 10))

    # Отрисовка результата работы модели
    for i in range(count):
        # Отображение на графике в первой линии предсказания модели
        axs[0, 0].set_title('Результат работы модели:')
        axs[0, i].imshow(orig[i])
        axs[0, i].axis('off')

        # Отображение на графике во второй линии сегментированного изображения из y_val
        axs[1, 0].set_title('Оригинальное сегментированное')
        axs[1, i].imshow(val_segments[indexes[i]])
        axs[1 ,i].axis('off')

        # Отображение на графике в третьей линии оригинального изображения
        axs[2, 0].set_title('Оригинальное изображение')
        axs[2, i].imshow(val_images[indexes[i]])
        axs[2 ,i].axis('off')

    plt.show()

# %% [markdown]
# **Распознавание**

# %%
# Отображение результатов работы модели

process_images(model_seq, 5)

# %% [markdown]
# Очень даже неплохо! Теперь мы вправе расчитывать, что получим отличные результаты с более мощной архитектурой, например, **U-Net**.

# %% [markdown]
# ## Архитектура U-Net

# %%
def unet(class_count,   # количество классов
         input_shape    # форма входного изображения
         ):

    img_input = Input(input_shape)                                          # Создаем входной слой формой input_shape

    ''' Block 1 '''
    x = Conv2D(64, (3, 3), padding='same', name='block1_conv1')(img_input)  # Добавляем Conv2D-слой с 64-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(64, (3, 3), padding='same', name='block1_conv2')(x)          # Добавляем Conv2D-слой с 64-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    block_1_out = Activation('relu')(x)                                     # Добавляем слой Activation и запоминаем в переменной block_1_out

    x = MaxPooling2D()(block_1_out)                                         # Добавляем слой MaxPooling2D

    ''' Block 2 '''
    x = Conv2D(128, (3, 3), padding='same', name='block2_conv1')(x)         # Добавляем Conv2D-слой с 128-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(128, (3, 3), padding='same', name='block2_conv2')(x)         # Добавляем Conv2D-слой с 128-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    block_2_out = Activation('relu')(x)                                     # Добавляем слой Activation и запоминаем в переменной block_2_out

    x = MaxPooling2D()(block_2_out)                                         # Добавляем слой MaxPooling2D

    ''' Block 3 '''
    x = Conv2D(256, (3, 3), padding='same', name='block3_conv1')(x)         # Добавляем Conv2D-слой с 256-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(256, (3, 3), padding='same', name='block3_conv2')(x)         # Добавляем Conv2D-слой с 256-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(256, (3, 3), padding='same', name='block3_conv3')(x)         # Добавляем Conv2D-слой с 256-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    block_3_out = Activation('relu')(x)                                     # Добавляем слой Activation и запоминаем в переменной block_3_out

    x = MaxPooling2D()(block_3_out)                                         # Добавляем слой MaxPooling2D

    ''' Block 4 '''
    x = Conv2D(512, (3, 3), padding='same', name='block4_conv1')(x)         # Добавляем Conv2D-слой с 512-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(512, (3, 3), padding='same', name='block4_conv2')(x)         # Добавляем Conv2D-слой с 512-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(512, (3, 3), padding='same', name='block4_conv3')(x)         # Добавляем Conv2D-слой с 512-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    block_4_out = Activation('relu')(x)                                     # Добавляем слой Activation и запоминаем в переменной block_4_out
    x = block_4_out

    ''' UP 2 '''
    x = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(x)     # Добавляем слой Conv2DTranspose с 256 нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = concatenate([x, block_3_out])                                       # Объединяем текущий слой со слоем block_3_out
    x = Conv2D(256, (3, 3), padding='same')(x)                              # Добавляем слой Conv2D с 256 нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    ''' UP 3 '''
    x = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(x)     # Добавляем слой Conv2DTranspose с 128 нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = concatenate([x, block_2_out])                                       # Объединяем текущий слой со слоем block_2_out
    x = Conv2D(128, (3, 3), padding='same')(x)                              # Добавляем слой Conv2D с 128 нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(128, (3, 3), padding='same')(x)                              # Добавляем слой Conv2D с 128 нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    ''' UP 4 '''
    x = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(x)      # Добавляем слой Conv2DTranspose с 64 нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = concatenate([x, block_1_out])                                       # Объединяем текущий слой со слоем block_1_out
    x = Conv2D(64, (3, 3), padding='same')(x)                               # Добавляем слой Conv2D с 64 нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(64, (3, 3), padding='same')(x)                               # Добавляем слой Conv2D с 64 нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(class_count, (3, 3), activation='softmax', padding='same')(x)  # Добавляем Conv2D-Слой с softmax-активацией на class_count-нейронов

    model = Model(img_input, x)                                             # Создаем модель с входом 'img_input' и выходом 'x'

    # Компилируем модель
    model.compile(optimizer=Adam(learning_rate=1e-4),
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])

    # Возвращаем сформированную модель
    return model

# %%
# Создание модели и вывод сводки по архитектуре

model_unet = unet(CLASS_COUNT,
                  (IMG_WIDTH, IMG_HEIGHT, 3))

model_unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 456, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 256, 456, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 456, 64) 256         block1_conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 456, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 256, 456, 64) 36928       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 456, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 456, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 228, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 128, 228, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 228, 128 512         block2_conv1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 228, 128 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 128, 228, 128 147584      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 228, 128 512         block2_conv2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 228, 128 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 114, 128) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 64, 114, 256) 295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 114, 256) 1024        block3_conv1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 114, 256) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 64, 114, 256) 590080      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 114, 256) 1024        block3_conv2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 114, 256) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 64, 114, 256) 590080      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 114, 256) 1024        block3_conv3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 114, 256) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 57, 256)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 32, 57, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 57, 512)  2048        block4_conv1[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 57, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 32, 57, 512)  2359808     activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 57, 512)  2048        block4_conv2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 57, 512)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 32, 57, 512)  2359808     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 57, 512)  2048        block4_conv3[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 57, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 64, 114, 256) 524544      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 64, 114, 256) 1024        conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 64, 114, 256) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 114, 512) 0           activation_10[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 114, 256) 1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 64, 114, 256) 1024        conv2d[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 64, 114, 256) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 114, 256) 590080      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 114, 256) 1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 114, 256) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 128, 228, 128 131200      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 128, 228, 128 512         conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 128, 228, 128 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 228, 256 0           activation_13[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 228, 128 295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 128, 228, 128 512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 128, 228, 128 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 228, 128 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128, 228, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 128, 228, 128 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 256, 456, 64) 32832       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 256, 456, 64) 256         conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 256, 456, 64) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 456, 128 0           activation_16[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 456, 64) 73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 256, 456, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 256, 456, 64) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 256, 456, 64) 36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 256, 456, 64) 256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 256, 456, 64) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 256, 456, 2)  1154        activation_18[0][0]
# ==================================================================================================
# Total params: 10,664,450
# Trainable params: 10,656,386
# Non-trainable params: 8,064
# __________________________________________________________________________________________________

# %%
# Обучение модели

history = model_unet.fit(x_train, y_train,
                         epochs=50, batch_size=12,
                         validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 78/78 [==============================] - 67s 604ms/step - loss: 0.1393 - sparse_categorical_accuracy: 0.9584 - val_loss: 0.2807 - val_sparse_categorical_accuracy: 0.8886
# Epoch 2/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0448 - sparse_categorical_accuracy: 0.9860 - val_loss: 0.3109 - val_sparse_categorical_accuracy: 0.8796
# Epoch 3/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0331 - sparse_categorical_accuracy: 0.9895 - val_loss: 0.2005 - val_sparse_categorical_accuracy: 0.9060
# Epoch 4/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0276 - sparse_categorical_accuracy: 0.9909 - val_loss: 0.0681 - val_sparse_categorical_accuracy: 0.9744
# Epoch 5/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0224 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0322 - val_sparse_categorical_accuracy: 0.9894
# Epoch 6/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0221 - sparse_categorical_accuracy: 0.9924 - val_loss: 0.0226 - val_sparse_categorical_accuracy: 0.9927
# Epoch 7/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0188 - sparse_categorical_accuracy: 0.9934 - val_loss: 0.0232 - val_sparse_categorical_accuracy: 0.9927
# Epoch 8/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0162 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.0224 - val_sparse_categorical_accuracy: 0.9928
# Epoch 9/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0167 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.0282 - val_sparse_categorical_accuracy: 0.9912
# Epoch 10/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0136 - sparse_categorical_accuracy: 0.9952 - val_loss: 0.0227 - val_sparse_categorical_accuracy: 0.9932
# Epoch 11/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0114 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.0223 - val_sparse_categorical_accuracy: 0.9935
# Epoch 12/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0111 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.0244 - val_sparse_categorical_accuracy: 0.9925
# Epoch 13/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0108 - sparse_categorical_accuracy: 0.9961 - val_loss: 0.0214 - val_sparse_categorical_accuracy: 0.9937
# Epoch 14/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0152 - sparse_categorical_accuracy: 0.9947 - val_loss: 0.0371 - val_sparse_categorical_accuracy: 0.9891
# Epoch 15/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0124 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.0216 - val_sparse_categorical_accuracy: 0.9939
# Epoch 16/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0099 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.0214 - val_sparse_categorical_accuracy: 0.9937
# Epoch 17/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0132 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.0303 - val_sparse_categorical_accuracy: 0.9914
# Epoch 18/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0131 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.0213 - val_sparse_categorical_accuracy: 0.9936
# Epoch 19/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0099 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0212 - val_sparse_categorical_accuracy: 0.9940
# Epoch 20/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0085 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0239 - val_sparse_categorical_accuracy: 0.9933
# Epoch 21/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9971 - val_loss: 0.0220 - val_sparse_categorical_accuracy: 0.9938
# Epoch 22/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0075 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0234 - val_sparse_categorical_accuracy: 0.9934
# Epoch 23/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.0224 - val_sparse_categorical_accuracy: 0.9941
# Epoch 24/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0218 - val_sparse_categorical_accuracy: 0.9942
# Epoch 25/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0075 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0506 - val_sparse_categorical_accuracy: 0.9840
# Epoch 26/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0085 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.0207 - val_sparse_categorical_accuracy: 0.9940
# Epoch 27/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0081 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0243 - val_sparse_categorical_accuracy: 0.9937
# Epoch 28/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.0217 - val_sparse_categorical_accuracy: 0.9943
# Epoch 29/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0063 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0237 - val_sparse_categorical_accuracy: 0.9939
# Epoch 30/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0063 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0239 - val_sparse_categorical_accuracy: 0.9940
# Epoch 31/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0059 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.0231 - val_sparse_categorical_accuracy: 0.9939
# Epoch 32/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0057 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0232 - val_sparse_categorical_accuracy: 0.9942
# Epoch 33/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0066 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0292 - val_sparse_categorical_accuracy: 0.9927
# Epoch 34/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0118 - sparse_categorical_accuracy: 0.9958 - val_loss: 1.1483 - val_sparse_categorical_accuracy: 0.8175
# Epoch 35/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0193 - sparse_categorical_accuracy: 0.9934 - val_loss: 0.0790 - val_sparse_categorical_accuracy: 0.9777
# Epoch 36/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0118 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.0217 - val_sparse_categorical_accuracy: 0.9936
# Epoch 37/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0099 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0207 - val_sparse_categorical_accuracy: 0.9943
# Epoch 38/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0207 - val_sparse_categorical_accuracy: 0.9938
# Epoch 39/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0066 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0218 - val_sparse_categorical_accuracy: 0.9939
# Epoch 40/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0061 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0227 - val_sparse_categorical_accuracy: 0.9938
# Epoch 41/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.0222 - val_sparse_categorical_accuracy: 0.9943
# Epoch 42/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0055 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0234 - val_sparse_categorical_accuracy: 0.9940
# Epoch 43/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0055 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0211 - val_sparse_categorical_accuracy: 0.9947
# Epoch 44/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0052 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0218 - val_sparse_categorical_accuracy: 0.9946
# Epoch 45/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0221 - val_sparse_categorical_accuracy: 0.9946
# Epoch 46/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0050 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0233 - val_sparse_categorical_accuracy: 0.9946
# Epoch 47/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0242 - val_sparse_categorical_accuracy: 0.9945
# Epoch 48/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0047 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0221 - val_sparse_categorical_accuracy: 0.9950
# Epoch 49/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0047 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0218 - val_sparse_categorical_accuracy: 0.9949
# Epoch 50/50
# 78/78 [==============================] - 44s 565ms/step - loss: 0.0046 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0256 - val_sparse_categorical_accuracy: 0.9944

# %%
# Отображение графиков обучения модели

plt.figure(figsize=(14, 7))
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.show()

# %% [markdown]
# **Распознавание**

# %%
# Отображение результатов работы модели

process_images(model_unet, 5)

# %% [markdown]
# Полученный результат выглядит очень мощно! Модель сегментирует даже самые мелкие детали.
#
# Теперь выведем **5** самых плохих по точности изображений проверочной выборки:

# %%
# Получение массива значений функции ошибки для каждого изображения из проверочной выборки

accuracy = np.array([model_unet.evaluate(x_val[i:i+1],
                                         y_val[i:i+1],
                                         verbose=0)[1] for i in range(x_val.shape[0])])

print(accuracy)
# Out:
# [0.99739581 0.99642783 0.99426055 0.9952457  0.99705321 0.99464601
#  0.99560547 0.99642783 0.99213612 0.9972074  0.99869794 0.99594814
#  0.99881786 0.99814969 0.97253633 0.99764425 0.99735302 0.99581105
#  0.9952628  0.99689901 0.99771279 0.99814111 0.99506581 0.9970789
#  0.99605948 0.99895489 0.99719024 0.99487734 0.94459295 0.99817538
#  0.99770421 0.99836385 0.99635077 0.98385245 0.99652207 0.98475194
#  0.99695897 0.99650496 0.99675333 0.99726737 0.99477452 0.99811542
#  0.99758428 0.99568254 0.99418348 0.99722451 0.99665058 0.98673934
#  0.99382365 0.99834669]

# %% [markdown]
# Мы получили массив **accuracy**, в котором сохранены значения **val_sparse_categorical_accuracy** для каждого изображения проверочной выборки. Выберем отсюда **5** худших значений:

# %%
# Получение индексов самых плохих по точности сегментации изображений

print('5 худших по точности сегментации изображений')
bad = np.argsort(accuracy)[:5].tolist()

for b in bad:
    print(f'Изображение №{b} - точность: {accuracy[b]}')
# Out:
# 5 худших по точности сегментации изображений
# Изображение №28 - точность: 0.9445929527282715
# Изображение №14 - точность: 0.9725363254547119
# Изображение №33 - точность: 0.9838524460792542
# Изображение №35 - точность: 0.9847519397735596
# Изображение №47 - точность: 0.9867393374443054

# %% [markdown]
# Выведем на экран результаты работы модели на этих изображениях:

# %%
# Вывод 5 изображений проверочной выборки, на которых модель дает наихудшие результаты

process_images(model_unet, indexes=bad)

# %% [markdown]
# **Содержание темы**
#
# 1. [Теория](https://colab.research.google.com/drive/1188DQBNnxXgxxZoldO8cXiQFYaO9PoOh?usp=sharing)
#
# 2. [Практический ноутбук 1](https://colab.research.google.com/drive/1EcHhwOCIhvm4mpxEbDGRawIJ4BpbAyqO?usp=sharing)
#
# 3. [Практический ноутбук 2](https://colab.research.google.com/drive/1pHONL5J4AVraE-SYJnpes7KdicPsD9qt?usp=sharing)
#
# 3. Практический ноутбук 3
