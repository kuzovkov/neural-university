# %% [markdown]
# <a href="https://colab.research.google.com/github/kuzovkov/neural-university/blob/main/%D0%91%D0%B0%D0%B7%D0%BE%D0%B2%D1%8B%D0%B9_%D0%B1%D0%BB%D0%BE%D0%BA_%7C_%D0%A1%D0%BE%D0%B7%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%D0%BF%D1%80%D0%BE%D1%81%D1%82%D0%BE%D0%B3%D0%BE_%D0%B2%D0%B5%D0%B1_%D1%81%D0%B5%D1%80%D0%B2%D0%B5%D1%80%D0%B0_%D0%B8_%D0%BD%D0%B0%D1%81%D1%82%D1%80%D0%BE%D0%B9%D0%BA%D0%B0_%D0%BF%D0%B0%D1%80%D0%B0%D0%BC%D0%B5%D1%82%D1%80%D0%BE%D0%B2_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D1%8B_%D0%BB%D0%BE%D0%BA%D0%B0%D0%BB%D1%8C%D0%BD%D0%BE%7C_%D0%A7%D0%B0%D1%81%D1%82%D1%8C_1_%7C_%D0%A3%D0%98%D0%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Создание простого веб-сервера и настройка параметров работы

# %% [markdown]
# Добрый день!
#
# Ранее вы изучили различные задачи машинного обучения и виды моделей, позволяющих их решать. На одном из занятий вы уже пробовали интегрировать нейронную сеть на демо-панель. В этом уроке мы сделаем следующий шаг в освоении способов интеграции. Будет рассмотрено создание сервиса, который позволит быстро и удобно загружать собственные данные для обработки их нейронной сетью, и способы размещения сервиса в сети.
#
#     План:
#
#     1. Создание демонстрационной формы c помощью библиотеки sreamlit
#     2. Развертывание демонстрационной формы на бесплатном хостинге

# %% [markdown]
# # Создание демонстрационной формы

# %% [markdown]
# ## Введение в Streamlit

# %% [markdown]
# **Streamlit** — это фреймворк с открытым кодом, специально разработанный для инженеров машинного обучения, работающих с **Python**. Он позволяет создавать стильные приложения буквально в несколько строк кода и помогает избежать разработки бэкенда и фронтенда сервиса с нуля.
#
# ---
# Документация: https://docs.streamlit.io/en/stable/

# %% [markdown]
# ## Использование библиотеки **Streamlit** на собственном компьютере

# %% [markdown]
#  Google Colaboratory, в котором вы работали до сих пор, является изолированной средой разработки. Подобную среду вы можете создать у себя на локальном компьютере.
#
#  #### Зачем нужны среды разработки?
# Почти каждый новый проект, который вы будете создавать, требует установки различных библиотек. Чтобы эти библиотеки согласованно работали, они должны быть определённых версий. Тогда проект будет работать. Обновление версий одной или нескольких библиотек, входящих в проект, уже после его создания может привести к конфликту версий. Работа проекта начнёт нарушаться, появятся ошибки. Чтобы этого не произошло, создают виртуальные среды, в которых установлены только нужные библиотеки нужных версий. Одним из инструментов создания таких сред является Анаконда.

# %% [markdown]
#  Если у вас ещё не установлен Python, его потребуется установить. Здесь подробная инструкция: [Установка Python.](https://colab.research.google.com/drive/1YTqa-8aa4ov7d_s6y3f8b0htlYvJqPnA?usp=sharing)

# %% [markdown]
# ---
# Дополнительная информация ([База знаний УИИ - «**Установка пакета "Anaconda"**»](https://colab.research.google.com/drive/18UhQBg_T3BcAhfQRkEBzpwznVlatdNpr?usp=sharing))
#
# ---

# %% [markdown]
# #### Шаг 1. Установка Anaconda
# 1. **Загрузить и установить Anaconda**:
#    - Установите пакет Анаконда, воспользовавшись инструкцией по ссылке выше.
#
# 2. **Запустить Anaconda Navigator**:
#    - После успешной установки, откройте **Anaconda Navigator** через меню «Пуск» или с рабочего стола.

# %% [markdown]
# ![Анаконда.jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  Панель Навигатора выглядит примерно так. Обратите внимание на две ячейки Jupyter Notebook и Powershell Prompt. В каждой из них должна быть синяя кнопка Launch. Если это так, значит, всё в порядке. Если вы видите зелёную Install, нажимайте. Произойдёт загрузка нужного инструмента в Анаконде, и кнопка станет синей Launch.
#
#  При установке Анаконды автоматически создаётся одна базовая виртуальная среда base.

# %% [markdown]
# #### Шаг 2. Создание новой среды в Anaconda
#
# Хотя `base` среда может работать, всегда лучше создать отдельную среду для каждого проекта:
#
# 1. В **Anaconda Navigator** выберите вкладку **Environments** и нажмите на кнопку **Create**.
# 2. Задайте имя среды, например, `streamlit_env` и выберите версию Python (рекомендуется Python 3.9 или выше).
# 3. Нажмите **Create**, и Anaconda создаст новую среду.

# %% [markdown]
# ![Анаконда 1.1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### Шаг 3. Установка Streamlit
#
# 1. **Активировать созданную среду**:
#    - Откройте терминал Anaconda (**Anaconda Prompt**) и активируйте среду:
#
#      ```bash
#      conda activate streamlit_env
#      ```
#
#    После этого в терминале должно появиться `(streamlit_env)` перед командной строкой.

# %% [markdown]
# Используйте именно терминал Анаконда, не путайте с классической командной строкой.

# %% [markdown]
# ![Анаконда 5.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Анаконда 6.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 2. **Установить Streamlit**:
#
#    В активированной среде выполните команду установки Streamlit:
#
#    ```bash
#    pip install streamlit
#    ```
#
# 3. **Проверить установку**:
#
#    Чтобы убедиться, что всё установлено корректно, запустите команду:
#
#    ```bash
#    streamlit hello
#    ```

# %% [markdown]
# ![Анаконда 7.jpg](data:image/jpeg;base64,...)

# %% [markdown]
#    Должна открыться демо-страница Streamlit в браузере с примером приложения.

# %% [markdown]
# ![Анаконда 8.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Может выскочить окно защитника. Снимите галочку с общественных сетей, установите на частные сети. И разрешите доступ.
#
# Всё, вы в демонстрационной панели **Streamlit**.

# %% [markdown]
# #### Шаг 4. Создание и запуск файла helloworld.py
#
# 1. **Где создавать файл?**:
#    - Рекомендуется использовать **Jupyter Notebook**, поскольку он уже установлен в Anaconda.

# %% [markdown]
# ![Анаконда 9.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Для возврата в панель Навигатора нажмите Home. Если в новой среде Jupyter Notebook не установлен, нажмите Install. Дождитесь окончания установки. Для запуска установленного инструмента нажмите Launch.
#
# Jupyter Notebook работает через браузер, поэтому не удивляйтесь, интерфейс работы откроется как новая вкладка браузера.

# %% [markdown]
# 2. **Создание файла `helloworld.py` в Jupyter Notebook**:
#    - Откройте **Jupyter Notebook** через Anaconda Navigator.
#    - Создайте новый Python-файл и добавьте следующий код:
#
#      ```python
#      import streamlit as st
#      import numpy as np
#      import pandas as pd
#
#      df = pd.DataFrame({
#          'first column': [1, 2, 3, 4],
#          'second column': [10, 20, 30, 40]
#      })
#      st.write(df)
#      ```

# %% [markdown]
# Так выглядит интерфейс jupyter ноутбука.

# %% [markdown]
# ![Анаконда 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Можете сначала выбрать одну из папок. Например, зайдём в Downloads. Те же два щелчка мышкой по папке и вы в ней. Там и создаём файл. Выбираем New - New File. По умолчанию предлагается создать текстовый файл, но нам нужен питоновский. Меняем название на helloworld.py

# %% [markdown]
# ![Анаконда.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 3. **Сохранение файла**:
#    - Открываем файл, копируем в него код. Сохраняем (File - Save All).

# %% [markdown]
# ![Анаконда 2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Теперь нам нужно запустить Streamlit с новым файлом. Но у нас до сих пор работает демонстрационная панель. Переходим в терминал. Нажимаем ctrl+C. Эта команда, выполненная в терминале, останавливает запущенные процессы. Если позже вы захотите что-то скопировать в терминале, можно воспользоваться сочетанием клавиш Shift+Ctrl+C.
#
# Практика показывает, что сочетание ctrl+V работает в привычном нам режиме. То есть, вставляет скопированные где-то данные. Например, путь до рабочей директории.

# %% [markdown]
# ![Анаконда 16.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 4. **Запуск Streamlit с файлом**:
#    - В терминале **Anaconda Prompt** (в активной среде `streamlit_env`), переместитесь в директорию, где был сохранён файл, командой:
#
#      ```bash
#      cd путь/к/директории
#      ```
#
#    - Запустите Streamlit с этим файлом:
#
#      ```bash
#      streamlit run helloworld.py
#      ```

# %% [markdown]
# ![Анаконда 2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 5. **Результат**:
#    Streamlit откроет браузер и отобразит DataFrame из файла. Это и есть первое Streamlit приложение.

# %% [markdown]
# ![Анаконда 2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Все работает отлично! Можно двигаться дальше.
#
# Библиотека **Streamlit** имеет широкий функционал и позволяет создавать графики, дашборды и карты, красиво визуализировать таблицы Pandas (**DataFrame**) и многое другое.

# %% [markdown]
# #### Отображение текста и данных

# %% [markdown]
# **Streamlit** поддерживает множество встроенных функций для форматирования текста.
#
# **Основные:**

# %% [markdown]
# * `st.title('...')` - задание названия приложения;
# * `st.header('...')`и `st.subheader('...')` - отображение заголовков разных уровней;
# * `st.json('...')`- отображение объекта или строки в виде красиво оформленной структуры **JSON**;
# * `st.text('...')` - простой текст, `st.markdown('...')` - текст с разметкой;
# * `st.latex('...')` - математические выражения a формате **LaTeX**.

# %% [markdown]
# Заменим содержимое нашего файла helloworld.py. Останавливаем работу Streamlit. Как? Вспоминайте.
#
# Заходим во вкладку нашего файла и меняем код:

# %%
import streamlit as st
import numpy as np
import pandas as pd

st.latex(r'a + ar + a r^2 + a r^3 + \cdots + a r^{n-1} = \sum_{k=0}^{n-1} ar^k = a \left(\frac{1-r^{n}}{1-r}\right)')

# %% [markdown]
# **Обратите внимание** на два момента при создании файла скрипта:
# * дробь создается с помощью ключевой конструкции `\frac`, но если Вы укажете просто `\frac`, то в текстовом файле `\f` заменится на символ
# . Чтобы избежать подобной ситуации иногда необходимо добавить еще один слеш
# * аналогично и для случая создания закрывающей правой скобки с помощью ключевой конструкции `\right`. `\r` - это символ переноса строки, поэтому, если у вас появится ошибка, добавьте еще один слеш.
#
# Снова запустите streamlit той же командой в терминале streamlit run helloworld.py. Проверьте корректность отображения формулы.

# %% [markdown]
# ![Анаконда 2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Есть один нюанс. Если у вас в браузере включён автоматический перевод на русский язык, некоторые буквы в формуле могут отображаться некорректно.

# %% [markdown]
# Для закрепления материала ещё пара примеров.

# %%
st.latex(r"""\int_{0}^{\infty} e^{-x^2} dx = \frac{\sqrt{\pi}}{2}""")
st.latex(r"""f(x) = \sum_{n=1}^{\infty} \frac{(-1)^{n+1}}{n} x^n""")

# %% [markdown]
# Вы можете попробовать также что-то из следующих методов:

# %% [markdown]
# `st.write('...')` - в зависимости
# от добавленного аргумента отображает:
#
# - `st.write(dict)` - словарь в интерактивном виджете;
# - `st.write(keras)` - модель Keras;
# - `st.write(func)` - информацию о функции ;
# - `st.write(plotly_fig)` - фигуру **Plotly**;
# - `st.write(data_frame)` - **DataFrame** как таблицу;
# - ...

# %% [markdown]
# Как выглядит вывод таблицы **Pandas** мы уже разбирали.

# %% [markdown]
# Подробнее в документации https://docs.streamlit.io/en/stable/api.html#.

# %% [markdown]
# Вы могли заметить, что код, в котором использовались библиотеки pandas и numpy, отрабатывался просто через импорт библиотек. Как в колабе. Это означает, что при создании новой среды в Анаконде часть библиотек устанавливается по умолчанию. Но иногда нам нужны и другие библиотеки. Рассмотрим такой пример.

# %% [markdown]
# #### Отображение диаграмм

# %% [markdown]
# * `st.line_chart(...)` - создание линейного графика;
# * `st.area_chart(...)` - диаграмма с областями;
# * `st.bar_chart(...)` - гистограмма;
# * `st.pyplot(...)` - график модуля **pyplot** библиотеки **matplotlib**.

# %% [markdown]
# Пробуем вывести гистограмму с использованием **matplotlib**. Снова меняем код и снова запускаем.

# %%
import numpy as np
import matplotlib.pyplot as plt

arr = np.random.normal(1, 1, size=100)
fig, ax = plt.subplots()
ax.hist(arr, bins=20)

st.pyplot(fig)

# %% [markdown]
# ![Анаконда 3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# И во вкладке streamlit и в терминале появляется ошибка. Лечится очень просто. Библиотеку нужно установить. Останавливаем панель, делаем установку библиотеки через pip, снова запускаем.

# %% [markdown]
# ![Анаконда 3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Всё работает.

# %% [markdown]
# ### Интерактивные элементы

# %% [markdown]
# С помощью виджетов **Streamlit** позволяет встроить взаимодействие с пользователем прямо в ваше приложение с помощью кнопок, ползунков, ввода текста и других элементов управления.

# %% [markdown]
# * `st.button()` - виджет кнопки;
# * `st.checkbox()` - виджет флажка;
# * `st.selectbox()` - виджет выбора;
# * `st.radio()` - виджет с переключателем;
# * `st.multiselect()` - виджет с множественным выбором, может запускаться со значениями по умолчанию.

# %% [markdown]
# Ниже приведен пример виджета с множественным выбором. Снова меняем код. На этот раз можете попробовать не останавливать панель. Меняете код. Сохраняете. Обновляете страницу панели.

# %%
import streamlit as st
import numpy as np
import pandas as pd

df = pd.DataFrame({
    'first column':[1, 2, 3, 4],
    'second column':[10, 20, 30, 40]
    })
st.write(df)

options = st.multiselect(
    'What are your favorite colors?',
    ['Green', 'Yellow', 'Red', 'Blue'],
    ['Yellow', 'Red'])

# %% [markdown]
# ![Анаконда 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ---
#
# **Важно!** Вы можете не только добавить интерактивности в свой отчет с помощью виджетов, но и организовать их в виде боковой панели с помощью `st.sidebar.<element_name>`.
#
# ---
#
# Каждый переданный в `st.sidebar` элемент будет закреплен слева, что позволит удобнее организовать для пользователя содержимое вашего приложения.
#
# Для элементов `st.echo()` и `st.spinner()` добавление в боковую панель не поддерживается.

# %% [markdown]
# ![Анаконда 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Отображение прогресса и статуса

# %% [markdown]
# **Streamlit** предоставляет несколько методов для добавления анимаций в ваше приложение. Эти анимации включают индикаторы выполнения, сообщения о состоянии (например, предупреждения) и праздничные шары.

# %% [markdown]
# * `st.progress()` - индикатор выполнения;
# * `st.error('This is an error')` - сообщение об ошибке;
# * `st.balloons()` - праздничные воздушные шары.

# %% [markdown]
# Пример - праздничные шары:

# %% [markdown]
# ![Анаконда 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Самостоятельно отработайте пример - создание искусственной длительной операции и вывод индикатора выполнения для нее:
# ```
# import time
#
# st.write('Starting a long computation...')
#
# # Add a placeholder
# latest_iteration = st.empty()
# bar = st.progress(0)
#
# for i in range(100):
#     # Update the progress bar with each iteration.
#     latest_iteration.text(f'Iteration {i+1}')
#     bar.progress(i + 1)
#     time.sleep(0.1)
# ```

# %% [markdown]
# ### Дополнительная информация

# %% [markdown]
# В этом занятии мы познакомились с очень полезным инструментом Анаконда, создали виртуальную среду для отдельного проекта, поработали с терминалом, разобрали базовый набор функций **Streamlit** для создания собственных приложений. Если вы столкнетесь с трудностями, вот несколько вещей, которые вы можете сделать:<br>
# 1. Посетите [форум сообщества](https://discuss.streamlit.io/) и задайте вопрос
# 2. Вызовите быструю справку из командной строки с помощью команды `streamlit --help`
# 3. Ознакомьтесь с [документацией](https://docs.streamlit.io/en/stable/api.html)
# 4. Ознакомьтесь с [примерами продвинутых приемов](https://docs.streamlit.io/en/stable/advanced_concepts.html)
