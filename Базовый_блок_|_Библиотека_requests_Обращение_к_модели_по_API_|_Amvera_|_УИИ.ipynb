# %% [markdown]
# <a href="https://colab.research.google.com/github/kuzovkov/neural-university/blob/main/%D0%91%D0%B0%D0%B7%D0%BE%D0%B2%D1%8B%D0%B9_%D0%B1%D0%BB%D0%BE%D0%BA_%7C_%D0%91%D0%B8%D0%B1%D0%BB%D0%B8%D0%BE%D1%82%D0%B5%D0%BA%D0%B0_requests_%D0%9E%D0%B1%D1%80%D0%B0%D1%89%D0%B5%D0%BD%D0%B8%D0%B5_%D0%BA_%D0%BC%D0%BE%D0%B4%D0%B5%D0%BB%D0%B8_%D0%BF%D0%BE_API_%7C_Amvera_%7C_%D0%A3%D0%98%D0%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Интеграция ML-решений: REST-архитектура

# %% [markdown]
# Ранее вы уже могли заметить, что создание модели является важным и достаточно сложным этапом разработки продукта с использованием машинного обучения (ML). Практика показывает, что создание инфраструктуры для использования модели оказывается не менее важной задачей.
#
# Самый простой вариант в этом случае - создание приложения (web-, мобильного или настольного) для доступа к обученной модели.
#
# Такая программа чаще всего представляет собой простое приложение-обертку с минималистичным интерфейсом, позволяющее загружать данные, обрабатывать их и получать результат, возвращаемый моделью.

# %% [markdown]
# Однако зачастую возникает необходимость в использовании ML-модели в рамках крупной системы, содержащей множество компонентов, отвечающих за ту или иную функциональность. В таком случае вам необходимо создать такой компонент, который будет отвечать за получение предсказаний от модели, и который будет совместим с другими компонентами системы.

# %% [markdown]
# Для этого потребуется изучить некоторые темы, связанные с web-разработкой и проектированием архитектуры приложений.
#
# В данном занятии:
# - разберем, что такое программные архитектуры **REST** и **API**, зачем они нужны;
# - вспомним, как создать свой веб-сервис, предоставляющий **API** для использования ML-модели,
# - разместим этот сервис на хостинге;
# - разберемся, как использовать сервис в сторонних приложениях или компонентах более крупного программного решения.

# %% [markdown]
# План:
#
# 0. Описание **REST** и **REST API**. Примеры на языке **Python**
# 1. Создание и обучение ML-модели, написание кода для инференса модели
# 2. Создание веб-сервиса с помощью **FastAPI**
# 3. Деплой (развертывание) сервиса на бесплатный хостинг

# %% [markdown]
# # 0. Описание REST и REST API. Примеры на языке Python

# %% [markdown]
# **_REST (Representational state transfer)_** – это стиль архитектуры программного обеспечения для распределенных систем, чаще всего используемый для построения веб-служб. Термин **REST** был введен в 2000 году Роем Филдингом, одним из авторов протокола **HTTP**. Системы, поддерживающие **REST**, называются **RESTful**-системами.

# %% [markdown]
# **REST**-архитектура определяет требования к построению распределенных приложений, направленные на улучшение их масштабируемости и производительности. Среди всех этих требований нас интересуют следующие:
# 1. Использование модели "клиент - сервер";
# 2. Единообразие интерфейса.

# %% [markdown]
# Еще одно важное понятие, которое требует разбора - **_API_** или **_Application Programming Interface_** (дословно: интерфейс прикладного программирования).
#
# **API** - это набор правил взаимодействия одной программы с другой. Речь в данном случае может идти как о веб-сервисах, так и о внутренних методах операционной системы или методах, предоставляемых какой-либо программной библиотекой.
#
# Например, бибиотека **Tensorflow** предоставляет **API** для таких языков, как **Python**, **С++**, **JavaScript** и **Java** - это значит, что писать и выполнять код, реализующий одни и те же операции, можно на любом из этих языков.

# %% [markdown]
# В данном занятии **API** будет рассматриваться только применительно к веб-сервисам. Кроме того, речь будет идти об **API** в контексте **REST**-архитектуры - так называемых **_RESTful API_**.

# %% [markdown]
# ![7bd2d33d-c5d6-41a9-9233-ace73a3f4ea1.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Разберем работу c протоколом REST более подробно.
#
# **REST API** позволяет использовать для взаимодействия между программами протокол **HTTP** (зашифрованная версия — **HTTPS**), с помощью которого мы получаем и отправляем большую часть информации в интернете.
#
# Протокол **HTTP** довольно прост. Рассмотрим его работу на примере.
#
# Допустим, есть адрес **http://website.com/samples**.
#
# Он состоит из двух частей: первая — это адрес сайта или сервера, то есть **http://website.com**.
#
# Вторая — адрес ресурса на удаленном сервере, в данном примере — **/samples**.
#
# Набирая в адресной строке URL-адрес **http://website.com/samples**, мы на самом деле отправляем запрос на сервер **website.com** и запрашиваем ресурс под названием **/samples**. «Пойди туда, принеси мне вот это» — и есть **HTTP**-запрос.
#
# Теперь представим, что по адресу **website.com** работает программа, к которой хочет обратиться другая программа. Чтобы программа понимала, какие именно функции нужны, для разных функций используются различные адреса.

# %% [markdown]
# ### Методы HTTP: основа работы REST API
#
# Чтобы ресурс, который вы запрашиваете, выполнял нужные действия, используются разные способы обращения к нему. Например, если вы работаете с выборками с помощью ресурса **/samples**, то можете их просматривать, редактировать или удалять.
#
# В **API**-системе четыре классических метода:
#
# 1. **GET** — метод чтения информации. **GET**-запросы всегда только возвращают данные с сервера, но никогда их не изменяют и не удаляют. Например, в приложении при помощи запроса **GET /samples** вы открываете список выборок данных.
#
# 2. **POST** — создание новых записей. В приложении запрос **POST /samples** будет использоваться для создания новой выборки.
#
# 3. **PUT** — редактирование записей. Например, запросом **PUT /samples** вы исправляете выборку.
#
# 4. **DELETE** — удаление записей. В нашем приложении запрос **DELETE /samples** удаляет старые или ненужные выборки.
#
# Таким образом, вы получаете четыре функции, которые программа может использовать при обращении к данным одного и того же ресурса, в примере — ресурса для работы со выборками **/samples**.

# %% [markdown]
# ### Для чего используют REST API
#
# Архитектура **REST API** — самое популярное решение для организации взаимодействия между различными программами. Так произошло, поскольку протокол **HTTP** реализован во всех языках программирования и всех операционных системах, в отличие от проприетарных протоколов.
#
# Чаще всего **REST API** применяют:
#
# - Для связи мобильных приложений с серверными;
# - Для построения микросервисных серверных приложений. Это архитектурный подход, при котором большие приложения разбиваются на много маленьких частей;
# - Для предоставления доступа к программам сторонних разработчиков. Например, **Stripe API** позволяет программистам встраивать обработку платежей в свои приложения.

# %% [markdown]
# ### Что еще важно знать при работе с REST API
#
# Каждый запрос **REST API** сообщает о результатах работы числовыми кодами — **_статусами HTTP_**.
#
# Например, редактирование записи на сервере может отработать успешно (код **200**), может быть заблокировано по соображениям безопасности (код **401** или **403**), а то и вообще сломаться в процессе из-за ошибки сервера (код **500**). Числовые коды ошибок — аналог пользовательских сообщений о результатах работы программы.
#
# Также **REST API** позволяет обмениваться не только текстовой информацией. С помощью этого инструмента можно передавать файлы и данные в специальных форматах: **_XML, JSON, Protobuf_**.

# %% [markdown]
# ### Шаблоны использования REST API
#
# Соглашения об использовании тех или иных **HTTP**-методов для различных функций в **REST** называются **_шаблонами REST_**, или **_REST-паттернами_**.
#
# В частности, разные паттерны по-разному рассматривают методы **POST** и **PUT**. Если **PUT** предназначен для создания, замены или редактирования, то для **POST** требования гораздо менее строги. Поэтому пример ниже будет правильным и в таком виде, и если поменять местами **POST** и **PUT**.
#
# Вообще говоря, **POST** может использоваться одновременно для всех действий изменения:
#
# - **POST /sample/** – добавление выборки (данные в теле запроса)
#
# - **POST /sample/3** – изменение конкретной выборки (данные в теле запроса)
#
# - **POST /sample/3** – удаление конкретной выборки (тело запроса пустое)
#
# Это позволяет иногда обходить неприятные моменты, связанные с использованием **PUT** и **DELETE**.
#
# Из приведенного примера можно видеть, что составленные определенным образом шаблоны (паттерны) **REST** позволяют обходится только одним типом запроса, например, **POST**. Остается лишь правильно сформировать тело запроса с командами и данными.

# %% [markdown]
# ### REST API и PYTHON
#
# Стандартная библиотека языка **Python** имеет ряд готовых модулей по работе с **HTTP**.
#
# - **urllib**
#
# - **httplib**
#
# Более низкий уровень обслуживает модуль **socket**.
#
# Но у всех этих модулей есть существенный недостаток - неудобство работы. Многие программисты любят **Python** за его элегантность и простоту, поэтому и был создан модуль, призванный решить эту проблему. Модуль называется **_requests_** (или "HTTP для людей").
#
# Рассмотрим реализацию основных методов **REST API** с использованием модуля **requests**.

# %% [markdown]
# Попробуем получить веб-страницу с помощью **GET**-запроса. В этом примере обратимся к общей ленте событий **GitHub**:

# %%
import requests
r = requests.get('https://api.github.com/events')

# %% [markdown]
# Мы получили объект **Response** с именем **r**. С помощью этого объекта можно получить всю необходимую информацию.
#
# Прикладной интерфейс (API) модуля **requests** прост: типы запросов **HTTP** очевидны. Ниже приведен пример вызова запроса **POST**:

# %%
r = requests.post('https://httpbin.org/post', data = {'key':'value'})

# %% [markdown]
# Другие типы запросов **HTTP**, такие как **PUT**, **DELETE**, **HEAD** и **OPTIONS** выполняются так же легко:

# %%
r = requests.put('https://httpbin.org/put', data = {'key':'value'})
r = requests.delete('https://httpbin.org/delete')
r = requests.head('https://httpbin.org/get')
r = requests.options('https://httpbin.org/get')

# %% [markdown]
# ### Передача параметров в URL
#
# Часто может понадобиться отправить какие-то данные в строке запроса **URL**. Если вы настраиваете **URL** вручную, то эти данные будут представлены в строке виде пар "ключ=значение" после знака вопроса.
#
# Например, **https://httpbin.org/get?key=val**.
#
# Модуль **requests** позволяет передать эти аргументы в качестве словаря, используя аргумент **params**. Если вы хотите передать `key1=value1` и `key2=value2` ресурсу **https://httpbin.org/get**, используйте  следующий код:

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get('https://httpbin.org/get', params=payload)
print(r.url)
# https://httpbin.org/get?key2=value2&key1=value1
# Out:
# https://httpbin.org/get?key1=value1&key2=value2

# %% [markdown]
# В качестве значения переменных можно передавать и списки:

# %%
payload = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.get('https://httpbin.org/get', params=payload)
print(r.url)
# https://httpbin.org/get?key1=value1&key2=value2&key2=value3
# Out:
# https://httpbin.org/get?key1=value1&key2=value2&key2=value3

# %% [markdown]
# ### Передача параметров в запросе POST
#
# А если надо отправить большой набор различных данных? Здесь пригодится формат данных **JSON**.

# %%
url = 'https://api.github.com/some/endpoint'
payload = {'some': 'data'}
r = requests.post(url, json=payload)

# %% [markdown]
# ### Содержимое ответа (объект Response)
#
# Вы можете прочитать содержимое ответа сервера на отправленный запрос.
#
# На примере ленты событий **GitHub** это выглядит так:

# %%
import requests
r = requests.get('https://api.github.com/events')
r.text
#'[{"repository":{"open_issues":0,"url":"https://github.com/...
# Out:
# '[{"id":"29846614775","type":"CreateEvent","actor":{"id":97210359,"login":"dapdelivery","display_login":"dapdelivery","gravatar_id":"","url":"https://api.github.com/users/dapdelivery","avatar_url":"https://avatars.githubusercontent.com/u/97210359?"},"repo":{"id":655642223,"name":"dapdelivery/where-for-dinner-19-06-2023-05-55-35-959965818","url":"https://api.github.com/repos/dapdelivery/where-for-dinner-19-06-2023-05-55-35-959965818"},"payload":{"ref":"main","ref_type":"branch","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2023-06-19T09:55:43Z"},{"id":"29846614749","type":"PullRequestReviewCommentEvent","actor":{"id":97177448,"login":"JonasKlauke","display_login":"JonasKlauke","gravatar_id":"","url":"https://api.github.com/users/JonasKlauke","avatar_url":"https://avatars.githubusercontent.com/u/97177448?"},"repo":{"id":123478787,"name":"soot-oss/SootUp","url":"https://api.github.com/repos/soot-oss/SootUp"},"payload":{"action":"created","comment":{"url":"https://api.github.com/repos/soot-oss/SootUp/pulls/comments/1233811242","pull_request_review_id":1485845310,"id":1233811242,"node_id":"PRRC_kwDOB1wjA85Jincq","diff_hunk":"@@ -129,6 +133,93 @@ public int callCount() {\\n     return graph.edgeSet().size();\\n   }\\n \\n+  @Override\\n+  public String exportAsDot() {\\n+    StringBuilder dotFormatBuilder = new StringBuilder();\\n+\\n+    graph.edgeSet().stream()\\n+        .sorted(\\n+            Comparator.comparing(\\n+                    (Edge edge) -> graph.getEdgeSource(edge).toString(), Comparator.naturalOrder())\\n+                .thenComparing(\\n+                    (Edge edge) -> graph.getEdgeTarget(edge).toString(), Comparator.naturalOrder()))\\n+        .forEach(\\n+            edge -> {\\n+              Vertex sourceVertex = graph.getEdgeSource(edge);\\n+              Vertex targetVertex = graph.getEdgeTarget(edge);\\n+              dotFormatBuilder\\n+                  .append(\\"\\\\t\\")\\n+                  .append(\\"\\\\\\"\\" + sourceVertex.methodSignature + \\"\\\\\\"\\")\\n+                  .append(\\" -> \\")\\n+                  .append(\\"\\\\\\"\\" + targetVertex.methodSignature + \\"\\\\\\"\\")\\n+                  .append(\\";\\\\n\\");\\n+            });\\n+    // Sort the callGraph\\n+    String sortedCallGraph = sortCallGraph(dotFormatBuilder.toString());\\n+\\n+    // Using only one string builder, so deleting everything and adding the sorted callgraph\\n+    dotFormatBuilder.delete(0, dotFormatBuilder.capacity());","path":"sootup.callgraph/src/main/java/sootup/callgraph/GraphBasedCallGraph.java","commit_id":"cb08bf51074a601541efb776a6bbb279c3c683b9","original_commit_id":"cb08bf51074a601541efb776a6bbb279c3c683b9","user":{"login":"JonasKlauke","id":97177448,"node_id":"U_kgDOBcrPaA","avatar_url":"https://avatars.githubusercontent.com/u/97177448?v=4","gravatar_id":"","url":"https://api.github.com/users/JonasKlauke","html_url":"https://github.com/JonasKlauke","followers_url":"https://api.github.com/users/JonasKlauke/followers","following_url":"https://api.github.com/users/JonasKlauke/following{/other_user}","gists_url":"https://api.github.com/users/JonasKlauke/gists{/gist_id}","starred_url":"https://api.github.com/users/JonasKlauke/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/JonasKlauke/subscriptions","organizations_url":"https://api.github.com/users/JonasKlauke/orgs","repos_url":"https://api.github.com/users/JonasKlauke/repos","events_url":"https://api.github.com/users/JonasKlauke/events{/privacy}","received_events_url":"https://api.github.com/users/JonasKlauke/received_events","type":"User","site_admin":false},"body":"Don\'t do this. \\r\\nInstead just return the string concatination \\r\\n\\"strict digraph ObjectGraph {\\\\n\\" + sortedCallgraph + \\"}\\"","created_at":"2023-06-19T09:51:33Z","updated_at":"2023-06-19T09:55:42Z","html_url":"https://github.com/soot-oss/SootUp/pull/618#discussion_r1233811242","pull_request_url": ...

# %% [markdown]
# Модуль **requests** будет автоматически декодировать содержимое ответа сервера. Большинство кодировок **unicode** декодируются без проблем.
#
# Когда вы делаете запрос, **requests** пытается определить кодировку на основании заголовков **HTTP**. Та же кодировка текста используется при обращении к **r.text**.
#
# Свойство **r.encoding** позволяет узнать, какую кодировку использует **requests** и при необходимости сменить её на другую.

# %% [markdown]
# ### Содержимое ответа в JSON
#
# Если вы работаете с данными в формате **JSON**, воспользуйтесь встроенным декодером **JSON**:

# %%
import requests
r = requests.get('https://api.github.com/events')
r.json()
# [{'repository': {'open_issues': 0, 'url': 'https://github.com/...
# Out:
# [{'id': '29846620838',
#   'type': 'PushEvent',
#   'actor': {'id': 87541280,
#    'login': 'WolseyBankWitness',
#    'display_login': 'WolseyBankWitness',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WolseyBankWitness',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/87541280?'},
#   'repo': {'id': 411743137,
#    'name': 'WolseyBankWitness/mhutchinson-distributor',
#    'url': 'https://api.github.com/repos/WolseyBankWitness/mhutchinson-distributor'},
#   'payload': {'repository_id': 411743137,
#    'push_id': 14030705651,
#    'size': 5,
#    'distinct_size': 0,
#    'ref': 'refs/heads/witness_wolsey-bank-alfred_2371c7aa76ca0d588c7f21317b789071bb63593bd2c3d7b02ca5842f03680fda',
#    'head': '78ab2cc3eb7e905400d18728f08caaf9971999a9',
#    'before': '50feed7a03850ca751928c8726ccb0e0e58ec2e3',
#    'commits': [{'sha': 'f2567dd2a758a0783892ed29d737f3b3f939e24b',
#      'author': {'email': '87541280+WolseyBankWitness@users.noreply.github.com',
#       'name': 'Wolsey Bank Witness'},
#      'message': 'Witness checkpoint@17972120',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/WolseyBankWitness/mhutchinson-distributor/commits/f2567dd2a758a0783892ed29d737f3b3f939e24b'},
#     {'sha': 'f44706752384600c36c4f31a3303f32e50e539e3',
#      'author': {'email': '87541280+WolseyBankWitness@users.noreply.github.com',
#       'name': 'Wolsey Bank Witness'},
#      'message': 'Witness checkpoint@4163431',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/WolseyBankWitness/mhutchinson-distributor/commits/f44706752384600c36c4f31a3303f32e50e539e3'},
#     {'sha': 'bea1a5b1e917261989d61126f1e0a006be1a426e',
#      'author': {'email': '87541280+WolseyBankWitness@users.noreply.github.com',
#       'name': 'Wolsey Bank Witness'},
#      'message': 'Witness checkpoint@20065868',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/WolseyBankWitness/mhutchinson-distributor/commits/bea1a5b1e917261989d61126f1e0a006be1a426e'},
#     {'sha': '32b53bdbcba78157d9daf3513bd5d3b9f5fbe2d6',
#      'author': {'email': '97608502+mhutchinson-witness@users.noreply.github.com',
#       'name': 'mhutchinson-witness'},
#      'message': 'Witness checkpoint@20065868',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/WolseyBankWitness/mhutchinson-distributor/commits/32b53bdbcba78157d9daf3513bd5d3b9f5fbe2d6'},
#     {'sha': '78ab2cc3eb7e905400d18728f08caaf9971999a9',
#      'author': {'email': 'actions@github.com', 'name': 'Serverless Bot'},
#      'message': 'Automatically merge witness signatures',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/WolseyBankWitness/mhutchinson-distributor/commits/78ab2cc3eb7e905400d18728f08caaf9971999a9'}]},
#   'public': True,
#   'created_at': '2023-06-19T09:55:57Z'},
#  {'id': '29846620833',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 39514782,
#    'login': 'sonarcloud[bot]',
#    'display_login': 'sonarcloud',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sonarcloud[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39514782?'},
#   'repo': {'id': 185143514,
#    'name': 'binary-com/deriv-app',
#    'url': 'https://api.github.com/repos/binary-com/deriv-app'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/binary-com/deriv-app/issues/6428',
#     'repository_url': 'https://api.github.com/repos/binary-com/deriv-app',
#     'labels_url': 'https://api.github.com/repos/binary-com/deriv-app/issues/6428/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/binary-com/deriv-app/issues/6428/comments',
#     'events_url': 'https://api.github.com/repos/binary-com/deriv-app/issues/6428/events',
#     'html_url': 'https://github.com/binary-com/deriv-app/pull/6428',
#     'id': 1366409920,
#     'node_id': 'PR_kwDOCwkQ2s4-mqm2',
#     'number': 6428,
#     'title': 'evgeniy /28452/ proof of income add',
#     'user': {'login': 'yauheni-deriv',
#      'id': 103182683,
#      'node_id': 'U_kgDOBiZxWw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/103182683?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/yauheni-deriv',
#      'html_url': 'https://github.com/yauheni-deriv',
#      'followers_url': 'https://api.github.com/users/yauheni-deriv/followers',
#      'following_url': 'https://api.github.com/users/yauheni-deriv/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/yauheni-deriv/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/yauheni-deriv/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/yauheni-deriv/subscriptions',
#      'organizations_url': 'https://api.github.com/users/yauheni-deriv/orgs',
#      'repos_url': 'https://api.github.com/users/yauheni-deriv/repos',
#      'events_url': 'https://api.github.com/users/yauheni-deriv/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/yauheni-deriv/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 2131961997,
#       'node_id': 'MDU6TGFiZWwyMTMxOTYxOTk3',
#       'url': 'https://api.github.com/repos/binary-com/deriv-app/labels/Account',
#       'name': 'Account',
#       'color': '920dbf',
#       'default': False,
#       'description': ''}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 5,
#     'created_at': '2022-09-08T14:06:39Z',
#     'updated_at': '2023-06-19T09:55:57Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/binary-com/deriv-app/pulls/6428',
#      'html_url': 'https://github.com/binary-com/deriv-app/pull/6428',
#      'diff_url': 'https://github.com/binary-com/deriv-app/pull/6428.diff',
#      'patch_url': 'https://github.com/binary-com/deriv-app/pull/6428.patch',
#      'merged_at': None},
#     'body': '## Changes:\r\n\r\nPlease include a summary of the change and which issue is fixed below:\r\n-   folders reordering and uploader refactoring started here, but isn’t merged yet:\r\nhttps://github.com/binary-com/deriv-app/pull/6349\r\n\r\n\r\n\r\n## When you need to add unit test\r\n\r\n-   [ ] If this change disrupt current flow\r\n-   [ ] If this change is adding new flow\r\n\r\n## When you need to add integration test\r\n\r\n-   [ ] If components from external libraries are being used to define the flow, e.g. @deriv/components\r\n-   [ ] If it relies on a very specific set of props with no default behavior for the current component.\r\n\r\n## Test coverage checklist (for reviewer)\r\n\r\n-   [ ] Ensure utility / function has a test case \r\n-   [ ] Ensure all the tests are passing\r\n\r\n## Type of change\r\n\r\n-   [ ] Bug fix\r\n-   [x] New feature\r\n-   [ ] Update feature\r\n-   [x] Refactor code\r\n-   [ ] Translation to code\r\n-   [ ] Translation to crowdin\r\n-   [ ] Script configuration\r\n-   [ ] Improve performance\r\n-   [ ] Style only\r\n-   [ ] Dependency update\r\n-   [ ] Documentation update\r\n-   [ ] Release\r\n',
#     'reactions': {'url': 'https://api.github.com/repos/binary-com/deriv-app/issues/6428/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/binary-com/deriv-app/issues/6428/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/binary-com/deriv-app/issues/comments/1596876641',
#     'html_url': 'https://github.com/binary-com/deriv-app/pull/6428#issuecomment-1596876641',
#     'issue_url': 'https://api.github.com/repos/binary-com/deriv-app/issues/6428',
#     'id': 1596876641,
#     'node_id': 'IC_kwDOCwkQ2s5fLmdh',
#     'user': {'login': 'sonarcloud[bot]',
#      'id': 39514782,
#      'node_id': 'MDM6Qm90Mzk1MTQ3ODI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/12526?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/sonarcloud%5Bbot%5D',
#      'html_url': 'https://github.com/apps/sonarcloud',
#      'followers_url': 'https://api.github.com/users/sonarcloud%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/sonarcloud%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/sonarcloud%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/sonarcloud%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/sonarcloud%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/sonarcloud%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/sonarcloud%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/sonarcloud%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/sonarcloud%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2023-06-19T09:55:57Z',
#     'updated_at': '2023-06-19T09:55:57Z',
#     'author_association': 'NONE',
#     'body': "Kudos, SonarCloud Quality Gate passed!&nbsp; &nbsp; [![Quality Gate passed](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/checks/QualityGateBadge/passed-16px.png 'Quality Gate passed')](https://sonarcloud.io/dashboard?id=binary-com_deriv-app&pullRequest=6428)\n\n[![Bug](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/common/bug-16px.png 'Bug')](https://sonarcloud.io/project/issues?id=binary-com_deriv-app&pullRequest=6428&resolved=false&types=BUG) [![A](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/checks/RatingBadge/A-16px.png 'A')](https://sonarcloud.io/project/issues?id=binary-com_deriv-app&pullRequest=6428&resolved=false&types=BUG) [0 Bugs](https://sonarcloud.io/project/issues?id=binary-com_deriv-app&pullRequest=6428&resolved=false&types=BUG)  \n[![Vulnerability](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/common/vulnerability-16px.png 'Vulnerability')](https://sonarcloud.io/project/issues?id=binary-com_deriv-app&pullRequest=6428&resolved=false&types=VULNERABILITY) [![A](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/checks/RatingBadge/A-16px.png 'A')](https://sonarcloud.io/project/issues?id=binary-com_deriv-app&pullRequest=6428&resolved=false&types=VULNERABILITY) [0 Vulnerabilities](https://sonarcloud.io/project/issues?id=binary-com_deriv-app&pullRequest=6428&resolved=false&types=VULNERABILITY)  \n[![Security Hotspot](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/common/security_hotspot-16px.png 'Security Hotspot')](https://sonarcloud.io/project/security_hotspots?id=binary-com_deriv-app&pullRequest=6428&resolved=false&types=SECURITY_HOTSPOT) [![A](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/checks/RatingBadge/A-16px.png 'A')](https://sonarcloud.io/project/security_hotspots?id=binary-com_deriv-app&pullRequest=6428&resolved=false&types=SECURITY_HOTSPOT) [0 Security Hotspots](https://sonarcloud.io/project/security_hotspots?id=binary-com_deriv-app&pullRequest=6428&resolved=false&types=SECURITY_HOTSPOT)  \n[![Code Smell](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/common/code_smell-16px.png 'Code Smell')](https://sonarcloud.io/project/issues?id=binary-com_deriv-app&pullRequest=6428&resolved=false&types=CODE_SMELL) [![A](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/checks/RatingBadge/A-16px.png 'A')](https://sonarcloud.io/project/issues?id=binary-com_deriv-app&pullRequest=6428&resolved=false&types=CODE_SMELL) [1 Code Smell](https://sonarcloud.io/project/issues?id=binary-com_deriv-app&pullRequest=6428&resolved=false&types=CODE_SMELL)\n\n[![No Coverage information](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/checks/CoverageChart/NoCoverageInfo-16px.png 'No Coverage information')](https://sonarcloud.io/component_measures?id=binary-com_deriv-app&pullRequest=6428) No Coverage information  \n[![2.5%](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/checks/Duplications/3-16px.png '2.5%')](https://sonarcloud.io/component_measures?id=binary-com_deriv-app&pullRequest=6428&metric=new_duplicated_lines_density&view=list) [2.5% Duplication](https://sonarcloud.io/component_measures?id=binary-com_deriv-app&pullRequest=6428&metric=new_duplicated_lines_density&view=list)\n\n",
#     'reactions': {'url': 'https://api.github.com/repos/binary-com/deriv-app/issues/comments/1596876641/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2023-06-19T09:55:57Z',
#   'org': {'id': 7437559,
#    'login': 'binary-com',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/binary-com',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7437559?'}},
#  {'id': '29846620804',
#   'type': 'PushEvent',
#   'actor': {'id': 137055812,
#    'login': 'TechnoTyphoon',
#    'display_login': 'TechnoTyphoon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TechnoTyphoon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/137055812?'},
#   'repo': {'id': 655640809,
#    'name': 'TechnoTyphoon/HTML-Portfolio',
#    'url': 'https://api.github.com/repos/TechnoTyphoon/HTML-Portfolio'},
#   'payload': {'repository_id': 655640809,
#    'push_id': 14030705674,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a59a71d92ea293f59656457fb496ac2f6c883551',
#    'before': '3476f3726230e747ae5d2da3d19a6108f88e7196',
#    'commits': [{'sha': 'a59a71d92ea293f59656457fb496ac2f6c883551',
#      'author': {'email': '137055812+TechnoTyphoon@users.noreply.github.com',
#       'name': 'Techno Official'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TechnoTyphoon/HTML-Portfolio/commits/a59a71d92ea293f59656457fb496ac2f6c883551'}]},
#   'public': True,
#   'created_at': '2023-06-19T09:55:57Z'},
#  {'id': '29846620884',
#   'type': 'CreateEvent',
#   'actor': {'id': 131740436,
#    'login': '9lumint',
#    'display_login': '9lumint',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/9lumint',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/131740436?'},
#   'repo': {'id': 629879619,
#    'name': 'alte-study/alte-study-1st',
#    'url': 'https://api.github.com/repos/alte-study/alte-study-1st'},
#   'payload': {'ref': 'week7_9lumint_dp_2',
#    'ref_type': 'branch',
#    'master_branch': 'dev',
#    'description': '알테스터디 1기 깃헙 레포지토리 입니다.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-06-19T09:55:57Z',
#   'org': {'id': 131244758,
#    'login': 'alte-study',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/alte-study',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/131244758?'}},
#  {'id': '29846620777',
#   'type': 'CreateEvent',
#   'actor': {'id': 87866479,
#    'login': 'Aldhaf',
#    'display_login': 'Aldhaf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Aldhaf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/87866479?'},
#   'repo': {'id': 655642352,
#    'name': 'Aldhaf/HabitHero',
#    'url': 'https://api.github.com/repos/Aldhaf/HabitHero'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-06-19T09:55:57Z'},
#  {'id': '29846620813',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 76565654,
#    'login': 'jean-humann',
#    'display_login': 'jean-humann',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jean-humann',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/76565654?'},
#   'repo': {'id': 639015245,
#    'name': 'jean-humann/docs-to-pdf',
#    'url': 'https://api.github.com/repos/jean-humann/docs-to-pdf'},
#   'payload': {'action': 'closed',
#    'number': 84,
#    'pull_request': {'url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/pulls/84',
#     'id': 1390930649,
#     'node_id': 'PR_kwDOJhaZTc5S5-rZ',
#     'html_url': 'https://github.com/jean-humann/docs-to-pdf/pull/84',
#     'diff_url': 'https://github.com/jean-humann/docs-to-pdf/pull/84.diff',
#     'patch_url': 'https://github.com/jean-humann/docs-to-pdf/pull/84.patch',
#     'issue_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/issues/84',
#     'number': 84,
#     'state': 'closed',
#     'locked': False,
#     'title': 'chore(deps-dev): bump @typescript-eslint/eslint-plugin from 5.59.9 to 5.59.11',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [@typescript-eslint/eslint-plugin](https://github.com/typescript-eslint/typescript-eslint/tree/HEAD/packages/eslint-plugin) from 5.59.9 to 5.59.11.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/typescript-eslint/typescript-eslint/releases"><code>@\u200btypescript-eslint/eslint-plugin</code>\'s releases</a>.</em></p>\n<blockquote>\n<h2>v5.59.11</h2>\n<h2><a href="https://github.com/typescript-eslint/typescript-eslint/compare/v5.59.10...v5.59.11">5.59.11</a> (2023-06-12)</h2>\n<p><strong>Note:</strong> Version bump only for package <code>@\u200btypescript-eslint/typescript-eslint</code></p>\n<h2>v5.59.10</h2>\n<h2><a href="https://github.com/typescript-eslint/typescript-eslint/compare/v5.59.9...v5.59.10">5.59.10</a> (2023-06-12)</h2>\n<p><strong>Note:</strong> Version bump only for package <code>@\u200btypescript-eslint/typescript-eslint</code></p>\n</blockquote>\n</details>\n<details>\n<summary>Changelog</summary>\n<p><em>Sourced from <a href="https://github.com/typescript-eslint/typescript-eslint/blob/main/packages/eslint-plugin/CHANGELOG.md"><code>@\u200btypescript-eslint/eslint-plugin</code>\'s changelog</a>.</em></p>\n<blockquote>\n<h2><a href="https://github.com/typescript-eslint/typescript-eslint/compare/v5.59.10...v5.59.11">5.59.11</a> (2023-06-12)</h2>\n<p><strong>Note:</strong> Version bump only for package <code>@\u200btypescript-eslint/eslint-plugin</code></p>\n<h2><a href="https://github.com/typescript-eslint/typescript-eslint/compare/v5.59.9...v5.59.10">5.59.10</a> (2023-06-12)</h2>\n<p><strong>Note:</strong> Version bump only for package <code>@\u200btypescript-eslint/eslint-plugin</code></p>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/typescript-eslint/typescript-eslint/commit/a91bb9e264544fc635a44468c2543b94fa83ac1c"><code>a91bb9e</code></a> chore: publish v5.59.11</li>\n<li><a href="https://github.com/typescript-eslint/typescript-eslint/commit/9768e989d332fb11c9cb6c72f8d1d707a0b59b95"><code>9768e98</code></a> chore: publish v5.59.10</li>\n<li>See full diff in <a href="https://github.com/typescript-eslint/typescript-eslint/commits/v5.59.11/packages/eslint-plugin">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=@typescript-eslint/eslint-plugin&package-manager=npm_and_yarn&previous-version=5.59.9&new-version=5.59.11)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ign ...
#     'created_at': '2023-06-13T16:04:48Z',
#     'updated_at': '2023-06-19T09:55:57Z',
#     'closed_at': '2023-06-19T09:55:56Z',
#     'merged_at': '2023-06-19T09:55:56Z',
#     'merge_commit_sha': 'bc60071ed713a06673ccc1b065908e12a7a16023',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 5491907956,
#       'node_id': 'LA_kwDOJhaZTc8AAAABR1fddA',
#       'url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/pulls/84/commits',
#     'review_comments_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/pulls/84/comments',
#     'review_comment_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/issues/84/comments',
#     'statuses_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/statuses/e07b8f8267a9a3a87613e5c0ac46a03cf6c1ed24',
#     'head': {'label': 'jean-humann:dependabot/npm_and_yarn/typescript-eslint/eslint-plugin-5.59.11',
#      'ref': 'dependabot/npm_and_yarn/typescript-eslint/eslint-plugin-5.59.11',
#      'sha': 'e07b8f8267a9a3a87613e5c0ac46a03cf6c1ed24',
#      'user': {'login': 'jean-humann',
#       'id': 76565654,
#       'node_id': 'MDQ6VXNlcjc2NTY1NjU0',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/76565654?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jean-humann',
#       'html_url': 'https://github.com/jean-humann',
#       'followers_url': 'https://api.github.com/users/jean-humann/followers',
#       'following_url': 'https://api.github.com/users/jean-humann/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jean-humann/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jean-humann/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jean-humann/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jean-humann/orgs',
#       'repos_url': 'https://api.github.com/users/jean-humann/repos',
#       'events_url': 'https://api.github.com/users/jean-humann/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jean-humann/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 639015245,
#       'node_id': 'R_kgDOJhaZTQ',
#       'name': 'docs-to-pdf',
#       'full_name': 'jean-humann/docs-to-pdf',
#       'private': False,
#       'owner': {'login': 'jean-humann',
#        'id': 76565654,
#        'node_id': 'MDQ6VXNlcjc2NTY1NjU0',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/76565654?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/jean-humann',
#        'html_url': 'https://github.com/jean-humann',
#        'followers_url': 'https://api.github.com/users/jean-humann/followers',
#        'following_url': 'https://api.github.com/users/jean-humann/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jean-humann/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/jean-humann/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jean-humann/subscriptions',
#        'organizations_url': 'https://api.github.com/users/jean-humann/orgs',
#        'repos_url': 'https://api.github.com/users/jean-humann/repos',
#        'events_url': 'https://api.github.com/users/jean-humann/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/jean-humann/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/jean-humann/docs-to-pdf',
#       'description': 'Generate PDF for document website 🧑\u200d🔧',
#       'fork': False,
#       'url': 'https://api.github.com/repos/jean-humann/docs-to-pdf',
#       'forks_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/forks',
#       'keys_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/teams',
#       'hooks_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/events',
#       'assignees_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/tags',
#       'blobs_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/languages',
#       'stargazers_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/subscription',
#       'commits_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/merges',
#       'archive_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/downloads',
#       'issues_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/deployments',
#       'created_at': '2023-05-10T15:18:32Z',
#       'updated_at': '2023-05-24T21:07:30Z',
#       'pushed_at': '2023-06-19T09:55:57Z',
#       'git_url': 'git://github.com/jean-humann/docs-to-pdf.git',
#       'ssh_url': 'git@github.com:jean-humann/docs-to-pdf.git',
#       'clone_url': 'https://github.com/jean-humann/docs-to-pdf.git',
#       'svn_url': 'https://github.com/jean-humann/docs-to-pdf',
#       'homepage': 'https://www.npmjs.com/package/docs-to-pdf',
#       'size': 22087,
#       'stargazers_count': 4,
#       'watchers_count': 4,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['documentation',
#        'docusaurus',
#        'docusaurus-documentation',
#        'pdf-generation'],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 4,
#       'default_branch': 'master'}},
#     'base': {'label': 'jean-humann:master',
#      'ref': 'master',
#      'sha': '812ad96b8e228a23206f7e3c2bbc3cbdbb0317f8',
#      'user': {'login': 'jean-humann',
#       'id': 76565654,
#       'node_id': 'MDQ6VXNlcjc2NTY1NjU0',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/76565654?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jean-humann',
#       'html_url': 'https://github.com/jean-humann',
#       'followers_url': 'https://api.github.com/users/jean-humann/followers',
#       'following_url': 'https://api.github.com/users/jean-humann/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jean-humann/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jean-humann/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jean-humann/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jean-humann/orgs',
#       'repos_url': 'https://api.github.com/users/jean-humann/repos',
#       'events_url': 'https://api.github.com/users/jean-humann/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jean-humann/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 639015245,
#       'node_id': 'R_kgDOJhaZTQ',
#       'name': 'docs-to-pdf',
#       'full_name': 'jean-humann/docs-to-pdf',
#       'private': False,
#       'owner': {'login': 'jean-humann',
#        'id': 76565654,
#        'node_id': 'MDQ6VXNlcjc2NTY1NjU0',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/76565654?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/jean-humann',
#        'html_url': 'https://github.com/jean-humann',
#        'followers_url': 'https://api.github.com/users/jean-humann/followers',
#        'following_url': 'https://api.github.com/users/jean-humann/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jean-humann/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/jean-humann/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jean-humann/subscriptions',
#        'organizations_url': 'https://api.github.com/users/jean-humann/orgs',
#        'repos_url': 'https://api.github.com/users/jean-humann/repos',
#        'events_url': 'https://api.github.com/users/jean-humann/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/jean-humann/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/jean-humann/docs-to-pdf',
#       'description': 'Generate PDF for document website 🧑\u200d🔧',
#       'fork': False,
#       'url': 'https://api.github.com/repos/jean-humann/docs-to-pdf',
#       'forks_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/forks',
#       'keys_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/teams',
#       'hooks_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/events',
#       'assignees_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/tags',
#       'blobs_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/languages',
#       'stargazers_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/subscription',
#       'commits_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/merges',
#       'archive_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/downloads',
#       'issues_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jean-humann/docs-to-pdf/deployments',
#       'created_at': '2023-05-10T15:18:32Z',
#       'updated_at': '2023-05-24T21:07:30Z',
#       'pushed_at': '2023-06-19T09:55:57Z',
#       'git_url': 'git://github.com/jean-humann/docs-to-pdf.git',
#       'ssh_url': 'git@github.com:jean-humann/docs-to-pdf.git',
#       'clone_url': 'https://github.com/jean-humann/docs-to-pdf.git',
#       'svn_url': 'https://github.com/jean-humann/docs-to-pdf',
#       'homepage': 'https://www.npmjs.com/package/docs-to-pdf',
#       'size': 22087,
#       'stargazers_count': 4,
#       'watchers_count': 4,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['documentation',
#        'docusaurus',
#        'docusaurus-documentation',
#        'pdf-generation'],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 4,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/jean-humann/docs-to-pdf/pulls/84'},
#      'html': {'href': 'https://github.com/jean-humann/docs-to-pdf/pull/84'},
#      'issue': {'href': 'https://api.github.com/repos/jean-humann/docs-to-pdf/issues/84'},
#      'comments': {'href': 'https://api.github.com/repos/jean-humann/docs-to-pdf/issues/84/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/jean-humann/docs-to-pdf/pulls/84/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/jean-humann/docs-to-pdf/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/jean-humann/docs-to-pdf/pulls/84/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/jean-humann/docs-to-pdf/statuses/e07b8f8267a9a3a87613e5c0ac46a03cf6c1ed24'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': {'enabled_by': {'login': 'jean-humann',
#       'id': 76565654,
#       'node_id': 'MDQ6VXNlcjc2NTY1NjU0',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/76565654?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jean-humann',
#       'html_url': 'https://github.com/jean-humann',
#       'followers_url': 'https://api.github.com/users/jean-humann/followers',
#       'following_url': 'https://api.github.com/users/jean-humann/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jean-humann/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jean-humann/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jean-humann/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jean-humann/orgs',
#       'repos_url': 'https://api.github.com/users/jean-humann/repos',
#       'events_url': 'https://api.github.com/users/jean-humann/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jean-humann/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'merge_method': 'squash',
#      'commit_title': 'chore(deps-dev): bump @typescript-eslint/eslint-plugin (#84)',
#      'commit_message': 'Bumps [@typescript-eslint/eslint-plugin](https://github.com/typescript-eslint/typescript-eslint/tree/HEAD/packages/eslint-plugin) from 5.59.9 to 5.59.11.\r\n- [Release notes](https://github.com/typescript-eslint/typescript-eslint/releases)\r\n- [Changelog](https://github.com/typescript-eslint/typescript-eslint/blob/main/packages/eslint-plugin/CHANGELOG.md)\r\n- [Commits](https://github.com/typescript-eslint/typescript-eslint/commits/v5.59.11/packages/eslint-plugin)\r\n\r\n---\r\nupdated-dependencies:\r\n- dependency-name: "@typescript-eslint/eslint-plugin"\r\n  dependency-type: direct:development\r\n  update-type: version-update:semver-patch\r\n...\r\n\r\nSigned-off-by: dependabot[bot] <support@github.com>\r\nCo-authored-by: dependabot[bot] <49699333+dependabot[bot]@users.noreply.github.com>'},
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'jean-humann',
#      'id': 76565654,
#      'node_id': 'MDQ6VXNlcjc2NTY1NjU0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/76565654?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jean-humann',
#      'html_url': 'https://github.com/jean-humann',
#      'followers_url': 'https://api.github.com/users/jean-humann/followers',
#      'following_url': 'https://api.github.com/users/jean-humann/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jean-humann/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jean-humann/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jean-humann/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jean-humann/orgs',
#      'repos_url': 'https://api.github.com/users/jean-humann/repos',
#      'events_url': 'https://api.github.com/users/jean-humann/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jean-humann/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 19,
#     'deletions': 53,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2023-06-19T09:55:57Z'},
#  {'id': '29846620783',
#   'type': 'CreateEvent',
#   'actor': {'id': 32761670,
#    'login': 'dhruv-chauhan',
#    'display_login': 'dhruv-chauhan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dhruv-chauhan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32761670?'},
#   'repo': {'id': 517087086,
#    'name': 'dhruv-chauhan/subgraphs',
#    'url': 'https://api.github.com/repos/dhruv-chauhan/subgraphs'},
#   'payload': {'ref': 'dashboard-lending-3.1.0',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Standardized subgraphs for blockchain data',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-06-19T09:55:57Z'},
#  {'id': '29846620849',
#   'type': 'PushEvent',
#   'actor': {'id': 22899166,
#    'login': 'Stefan-Stojanovic',
#    'display_login': 'Stefan-Stojanovic',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Stefan-Stojanovic',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22899166?'},
#   'repo': {'id': 75077147,
#    'name': 'enkidevs/curriculum',
#    'url': 'https://api.github.com/repos/enkidevs/curriculum'},
#   'payload': {'repository_id': 75077147,
#    'push_id': 14030705666,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/Stefan-Stojanovic-patch-11',
#    'head': '6db825afc08759d0105a2281ce5f3c6543387caf',
#    'before': 'e033e447f60b6efab3589f66d74aec808c3b45d5',
#    'commits': [{'sha': '6db825afc08759d0105a2281ce5f3c6543387caf',
#      'author': {'email': 'Stefan-Stojanovic@users.noreply.github.com',
#       'name': 'Stefan Stojanovic'},
#      'message': 'Update CHANGELOG.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/enkidevs/curriculum/commits/6db825afc08759d0105a2281ce5f3c6543387caf'}]},
#   'public': True,
#   'created_at': '2023-06-19T09:55:57Z',
#   'org': {'id': 12428872,
#    'login': 'enkidevs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/enkidevs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12428872?'}},
#  {'id': '29846620808',
#   'type': 'PushEvent',
#   'actor': {'id': 106295287,
#    'login': 'tudubucket',
#    'display_login': 'tudubucket',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tudubucket',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/106295287?'},
#   'repo': {'id': 655028814,
#    'name': 'tudubucket/blocksmc-tracker',
#    'url': 'https://api.github.com/repos/tudubucket/blocksmc-tracker'},
#   'payload': {'repository_id': 655028814,
#    'push_id': 14030705681,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0518fca76ae2e4831a915c16b13deaecbef8f233',
#    'before': '85c2847b4500df65b0ca3f8d6c5072e9e4938ff0',
#    'commits': [{'sha': '0518fca76ae2e4831a915c16b13deaecbef8f233',
#      'author': {'email': '106295287+tudubucket@users.noreply.github.com',
#       'name': 'tudubucket'},
#      'message': 'UTC 19-06-2023 16:55:23: Automatic commit, sync player statistics',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tudubucket/blocksmc-tracker/commits/0518fca76ae2e4831a915c16b13deaecbef8f233'}]},
#   'public': True,
#   'created_at': '2023-06-19T09:55:57Z'},
#  {'id': '29846620839',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 579726470,
#    'name': '0xbigz/drift-v2-orderbook-snap',
#    'url': 'https://api.github.com/repos/0xbigz/drift-v2-orderbook-snap'},
#   'payload': {'repository_id': 579726470,
#    'push_id': 14030705584,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '347caf1ccdee6eaecc070977c69a7d1fa4a1c7b5',
#    'before': '2fdc671ddae7c36aa482b746399ea33aab035f1d',
#    'commits': [{'sha': '347caf1ccdee6eaecc070977c69a7d1fa4a1c7b5',
#      'author': {'email': 'action@github.com', 'name': 'GitHub Action'},
#      'message': '2023-06-19 09:55:53',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/0xbigz/drift-v2-orderbook-snap/commits/347caf1ccdee6eaecc070977c69a7d1fa4a1c7b5'}]},
#   'public': True,
#   'created_at': '2023-06-19T09:55:57Z'},
#  {'id': '29846620766',
#   'type': 'PushEvent',
#   'actor': {'id': 26217027,
#    'login': 'MichaelBengtsson',
#    'display_login': 'MichaelBengtsson',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MichaelBengtsson',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26217027?'},
#   'repo': {'id': 593139604,
#    'name': 'krokedil/wc-test-helper',
#    'url': 'https://api.github.com/repos/krokedil/wc-test-helper'},
#   'payload': {'repository_id': 593139604,
#    'push_id': 14030705678,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ed6af772572126ee7d5e58978d83219e3025e23d',
#    'before': '03d6098753cc1264c2c8d46b57219d78ccd787eb',
#    'commits': [{'sha': 'ed6af772572126ee7d5e58978d83219e3025e23d',
#      'author': {'email': 'github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'bump: version 1.0.3 → 1.0.4',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/krokedil/wc-test-helper/commits/ed6af772572126ee7d5e58978d83219e3025e23d'}]},
#   'public': True,
#   'created_at': '2023-06-19T09:55:57Z',
#   'org': {'id': 7773475,
#    'login': 'krokedil',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/krokedil',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7773475?'}},
#  {'id': '29846620810',
#   'type': 'IssuesEvent',
#   'actor': {'id': 52227176,
# ...
#      'node_id': 'MDQ6VXNlcjE4NzE5MTI3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/18719127?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/xmudrii',
#      'html_url': 'https://github.com/xmudrii',
#      'followers_url': 'https://api.github.com/users/xmudrii/followers',
#      'following_url': 'https://api.github.com/users/xmudrii/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/xmudrii/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/xmudrii/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/xmudrii/subscriptions',
#      'organizations_url': 'https://api.github.com/users/xmudrii/orgs',
#      'repos_url': 'https://api.github.com/users/xmudrii/repos',
#      'events_url': 'https://api.github.com/users/xmudrii/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/xmudrii/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2023-06-19T09:55:56Z',
#     'updated_at': '2023-06-19T09:55:56Z',
#     'author_association': 'MEMBER',
#     'body': '/remove-lifecycle stale',
#     'reactions': {'url': 'https://api.github.com/repos/kubernetes/release/issues/comments/1596876637/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2023-06-19T09:55:57Z',
#   'org': {'id': 13629408,
#    'login': 'kubernetes',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/kubernetes',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13629408?'}},
#  {'id': '29846620576',
#   'type': 'WatchEvent',
#   'actor': {'id': 1843423,
#    'login': 'tiggerlee',
#    'display_login': 'tiggerlee',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tiggerlee',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1843423?'},
#   'repo': {'id': 468576060,
#    'name': 'openai/openai-cookbook',
#    'url': 'https://api.github.com/repos/openai/openai-cookbook'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-06-19T09:55:57Z',
#   'org': {'id': 14957082,
#    'login': 'openai',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/openai',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14957082?'}},
#  {'id': '29846620572',
#   'type': 'PushEvent',
#   'actor': {'id': 61745669,
#    'login': 'wiecek1873',
#    'display_login': 'wiecek1873',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wiecek1873',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61745669?'},
#   'repo': {'id': 653748584,
#    'name': 'wiecek1873/GameDevJobs',
#    'url': 'https://api.github.com/repos/wiecek1873/GameDevJobs'},
#   'payload': {'repository_id': 653748584,
#    'push_id': 14030705548,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'aea372a270b4223404769f8834067740f4577b03',
#    'before': 'e8aa5cc2a048cd539a3e535ccf982f6739c5ef61',
#    'commits': [{'sha': 'aea372a270b4223404769f8834067740f4577b03',
#      'author': {'email': 'wiecek1873@gmail.com', 'name': 'Michał Więcek'},
#      'message': 'Added async to method names',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wiecek1873/GameDevJobs/commits/aea372a270b4223404769f8834067740f4577b03'}]},
#   'public': True,
#   'created_at': '2023-06-19T09:55:57Z'},
#  {'id': '29846620568',
#   'type': 'CreateEvent',
#   'actor': {'id': 66119853,
#    'login': 'okikioriola1',
#    'display_login': 'okikioriola1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/okikioriola1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66119853?'},
#   'repo': {'id': 655639552,
#    'name': 'okikioriola1/alaro-city-demo',
#    'url': 'https://api.github.com/repos/okikioriola1/alaro-city-demo'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-06-19T09:55:57Z'},
#  {'id': '29846620483',
#   'type': 'PushEvent',
#   'actor': {'id': 103111402,
#    'login': 'CrissJordanY',
#    'display_login': 'CrissJordanY',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CrissJordanY',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103111402?'},
#   'repo': {'id': 655580501,
#    'name': 'CrissJordanY/hackathon',
#    'url': 'https://api.github.com/repos/CrissJordanY/hackathon'},
#   'payload': {'repository_id': 655580501,
#    'push_id': 14030705506,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '512c39589d223280456c7c1b5144f73ea2a34e93',
#    'before': '5e9836c594c18c25d8e4904e000c2d94e402879d',
#    'commits': [{'sha': '512c39589d223280456c7c1b5144f73ea2a34e93',
#      'author': {'email': '103111402+CrissJordanY@users.noreply.github.com',
#       'name': 'CrissJordanY'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/CrissJordanY/hackathon/commits/512c39589d223280456c7c1b5144f73ea2a34e93'}]},
#   'public': True,
#   'created_at': '2023-06-19T09:55:56Z'},
#  {'id': '29846620481',
#   'type': 'PushEvent',
#   'actor': {'id': 6707002,
#    'login': 'mbeckem',
#    'display_login': 'mbeckem',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mbeckem',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6707002?'},
#   'repo': {'id': 589585125,
#    'name': 'open-pioneer/demo',
#    'url': 'https://api.github.com/repos/open-pioneer/demo'},
#   'payload': {'repository_id': 589585125,
#    'push_id': 14030705523,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '2fd6258e917f50227e5725d2a97e00f267274fe2',
#    'before': 'b25ded4f4eba2e0fc4f64c16520e0a5286079282',
#    'commits': [{'sha': '2fd6258e917f50227e5725d2a97e00f267274fe2',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploying to gh-pages from @ open-pioneer/core-packages@c7b3e9f858c23eee2c11996c2a150642d3dcbe93 🚀',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/open-pioneer/demo/commits/2fd6258e917f50227e5725d2a97e00f267274fe2'}]},
#   'public': True,
#   'created_at': '2023-06-19T09:55:56Z',
#   'org': {'id': 121286957,
#    'login': 'open-pioneer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/open-pioneer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/121286957?'}},
#  {'id': '29846620537',
#   'type': 'IssuesEvent',
#   'actor': {'id': 54112038,
#    'login': 'YJDoc2',
#    'display_login': 'YJDoc2',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/YJDoc2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54112038?'},
#   'repo': {'id': 73984862,
#    'name': 'kivikakk/comrak',
#    'url': 'https://api.github.com/repos/kivikakk/comrak'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/kivikakk/comrak/issues/324',
#     'repository_url': 'https://api.github.com/repos/kivikakk/comrak',
#     'labels_url': 'https://api.github.com/repos/kivikakk/comrak/issues/324/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/kivikakk/comrak/issues/324/comments',
#     'events_url': 'https://api.github.com/repos/kivikakk/comrak/issues/324/events',
#     'html_url': 'https://github.com/kivikakk/comrak/issues/324',
#     'id': 1763176904,
#     'node_id': 'I_kwDOBGjrXs5pF_HI',
#     'number': 324,
#     'title': '[RFC] CI for running Benchmarks',
#     'user': {'login': 'YJDoc2',
#      'id': 54112038,
#      'node_id': 'MDQ6VXNlcjU0MTEyMDM4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/54112038?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/YJDoc2',
#      'html_url': 'https://github.com/YJDoc2',
#      'followers_url': 'https://api.github.com/users/YJDoc2/followers',
#      'following_url': 'https://api.github.com/users/YJDoc2/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/YJDoc2/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/YJDoc2/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/YJDoc2/subscriptions',
#      'organizations_url': 'https://api.github.com/users/YJDoc2/orgs',
#      'repos_url': 'https://api.github.com/users/YJDoc2/repos',
#      'events_url': 'https://api.github.com/users/YJDoc2/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/YJDoc2/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2023-06-19T09:55:56Z',
#     'updated_at': '2023-06-19T09:55:56Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'body': 'Given that there are quite a few enhancements requested (https://github.com/kivikakk/comrak/issues/291 and linked in its desc), there will be code changes that potentially change the processing path or structures to implement them. As this is a parsing library and has speed as a concern, there should be a way to track change in processing time along with commits.\r\n\r\nCurrently I think there are benchmarks in makefile, so we should probably allow running them on github itself through CI. One way can be to run on each push, other would be to run through comment.\r\n\r\nWould a PR on this welcome? Any suggestions on how to do benchmarks apart from the makefile and/or approach?\r\n\r\nThanks!',
#     'reactions': {'url': 'https://api.github.com/repos/kivikakk/comrak/issues/324/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/kivikakk/comrak/issues/324/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None}},
#   'public': True,
#   'created_at': '2023-06-19T09:55:56Z'},
#  {'id': '29846620430',
#   'type': 'ForkEvent',
#   'actor': {'id': 68948796,
#    'login': 'NieShenRuc',
#    'display_login': 'NieShenRuc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NieShenRuc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68948796?'},
#   'repo': {'id': 591396018,
#    'name': 'deep-floyd/IF',
#    'url': 'https://api.github.com/repos/deep-floyd/IF'},
#   'payload': {'forkee': {'id': 655642350,
#     'node_id': 'R_kgDOJxRO7g',
#     'name': 'IF',
#     'full_name': 'NieShenRuc/IF',
#     'private': False,
#     'owner': {'login': 'NieShenRuc',
#      'id': 68948796,
#      'node_id': 'MDQ6VXNlcjY4OTQ4Nzk2',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/68948796?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/NieShenRuc',
#      'html_url': 'https://github.com/NieShenRuc',
#      'followers_url': 'https://api.github.com/users/NieShenRuc/followers',
#      'following_url': 'https://api.github.com/users/NieShenRuc/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/NieShenRuc/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/NieShenRuc/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/NieShenRuc/subscriptions',
#      'organizations_url': 'https://api.github.com/users/NieShenRuc/orgs',
#      'repos_url': 'https://api.github.com/users/NieShenRuc/repos',
#      'events_url': 'https://api.github.com/users/NieShenRuc/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/NieShenRuc/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/NieShenRuc/IF',
#     'description': None,
#     'fork': True,
#     'url': 'https://api.github.com/repos/NieShenRuc/IF',
#     'forks_url': 'https://api.github.com/repos/NieShenRuc/IF/forks',
#     'keys_url': 'https://api.github.com/repos/NieShenRuc/IF/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/NieShenRuc/IF/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/NieShenRuc/IF/teams',
#     'hooks_url': 'https://api.github.com/repos/NieShenRuc/IF/hooks',
#     'issue_events_url': 'https://api.github.com/repos/NieShenRuc/IF/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/NieShenRuc/IF/events',
#     'assignees_url': 'https://api.github.com/repos/NieShenRuc/IF/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/NieShenRuc/IF/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/NieShenRuc/IF/tags',
#     'blobs_url': 'https://api.github.com/repos/NieShenRuc/IF/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/NieShenRuc/IF/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/NieShenRuc/IF/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/NieShenRuc/IF/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/NieShenRuc/IF/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/NieShenRuc/IF/languages',
#     'stargazers_url': 'https://api.github.com/repos/NieShenRuc/IF/stargazers',
#     'contributors_url': 'https://api.github.com/repos/NieShenRuc/IF/contributors',
#     'subscribers_url': 'https://api.github.com/repos/NieShenRuc/IF/subscribers',
#     'subscription_url': 'https://api.github.com/repos/NieShenRuc/IF/subscription',
#     'commits_url': 'https://api.github.com/repos/NieShenRuc/IF/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/NieShenRuc/IF/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/NieShenRuc/IF/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/NieShenRuc/IF/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/NieShenRuc/IF/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/NieShenRuc/IF/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/NieShenRuc/IF/merges',
#     'archive_url': 'https://api.github.com/repos/NieShenRuc/IF/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/NieShenRuc/IF/downloads',
#     'issues_url': 'https://api.github.com/repos/NieShenRuc/IF/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/NieShenRuc/IF/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/NieShenRuc/IF/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/NieShenRuc/IF/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/NieShenRuc/IF/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/NieShenRuc/IF/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/NieShenRuc/IF/deployments',
#     'created_at': '2023-06-19T09:55:55Z',
#     'updated_at': '2023-06-19T09:55:56Z',
#     'pushed_at': '2023-06-02T19:06:46Z',
#     'git_url': 'git://github.com/NieShenRuc/IF.git',
#     'ssh_url': 'git@github.com:NieShenRuc/IF.git',
#     'clone_url': 'https://github.com/NieShenRuc/IF.git',
#     'svn_url': 'https://github.com/NieShenRuc/IF',
#     'homepage': None,
#     'size': 28795,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2023-06-19T09:55:56Z',
#   'org': {'id': 101987939,
#    'login': 'deep-floyd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/deep-floyd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101987939?'}}]

# %% [markdown]
# Если декодирование в **JSON** не удалось, `r.json()` вызовет ошибку (исключение). Например, если сервер ответил кодом **204** (No Content), либо ответ содержит неправильный по формату **JSON**, то попытка обращения к `r.json()` приведет к ошибке **ValueError: No JSON object could be decoded**.
#
# Следует иметь в виду, что успешный вызов `r.json()` не означает, что ответ сервера был успешным. Некоторые серверы могут возвращать объект **JSON** и при неудачном ответе (например, сведения об ошибке **HTTP 500**). Такой объект **JSON** будет декодирован при вызове `r.json()` и успешно возвращен. Чтобы проверить, успешен ли был запрос, используйте `r.raise_for_status()` или проверьте содержимое **r.status_code**.

# %% [markdown]
# # 1. Создание и обучение ML-модели, написание кода для инференса (режима предсказания) модели

# %% [markdown]
# Для дальнейшей работы воспользуемся моделью, изученной на одном из первых занятий, для классификации автомобилей по трем маркам: **Ferrari**, **Renault** и **Mercedes**.
#
# В рамках данного этапа работы мы должны создать файл с кодом для:
# - инициализации модели;
# - загрузки ее весов;
# - предобработки изображения;
# - подачи его в сеть и получения предсказания.
#
# Также нам нужно загрузить файл с весами в ноутбук для последующей отправки на удаленный сервер.

# %% [markdown]
# Загрузим модель из облака:

# %%
import gdown

# Загрузка файла модели из облака
gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l16/cars3.h5', None, quiet=True)
# Out:
# 'cars3.h5'

# %% [markdown]
# Создадим файл с кодом для инициализации модели, загрузки весов, предобработки изображения и инференса (режима предсказания) модели:

# %%
predict_file = '''

from tensorflow.keras.models import load_model
import numpy as np
from io import BytesIO
from PIL import Image

INPUT_SHAPE = (96, 54, 3)

model = load_model('cars3.h5')  # Инициализация модели


def process(image_file):

    # Открытие обрабатываемого файла
    image = Image.open(BytesIO(image_file))

    # Изменение размера изображения в соответствии со входом сети
    resized_image = image.resize((INPUT_SHAPE[1], INPUT_SHAPE[0]))

    # Подгонка формы тензора для подачи в модель
    array = np.array(resized_image)[np.newaxis, ...]

    # Запуск предсказания
    prediction_array = model.predict(array)[0]

    # Возврат предсказания сети в виде текстовой переменной, хранящей список
    return str(list(prediction_array))
'''

# Сохранение кода в файл
with open('predict.py', 'w') as file:
    file.write(predict_file)

# %% [markdown]
# # 2. Создание веб-сервиса с помощью FastAPI

# %% [markdown]
# В данном разделе будет создан веб-сервис, предоставляющий API для получения предсказания из модели нейронной сети.

# %% [markdown]
# Существует большое количество веб-фреймворков, позволяющих это сделать, например, **Flask** или **Django**. Однако последние содержат слишком много функций для разработки веб-приложений, которые нам просто не понадобятся (мы не будем работать с веб-страницами, обращаться к базам данных и т.п.).
#
# Поэтому воспользуемся специализированным веб-фреймворком, который был разработан специально для создания API - **_FastAPI_**.

# %% [markdown]
# Для начала разберемся, как создавать веб-сервисы с помощью **FastAPI** и обращаться к созданному API. Также в конце раздела сохраним наши наработки в файл для будущего его размещения на сервере хостинга.

# %% [markdown]
# [Документация FAST API](https://fastapi.tiangolo.com/)

# %% [markdown]
# Установим библиотеку **FastAPI** и вспомогательные компоненты:

# %%
# !pip install fastapi
# !pip install uvicorn
# !pip install python-multipart
# Out:
# Requirement already satisfied: fastapi in /usr/local/lib/python3.12/dist-packages (0.116.2)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi) (0.48.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from fastapi) (2.11.9)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from fastapi) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette<0.49.0,>=0.40.0->fastapi) (4.10.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.6.2->starlette<0.49.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.6.2->starlette<0.49.0,>=0.40.0->fastapi) (1.3.1)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (0.35.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn) (8.2.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.12/dist-packages (0.0.20)

# %% [markdown]
# Создадим файл с тестовым API:

# %%
main_file = '''from fastapi import FastAPI

app = FastAPI()

@app.get("/test")
def read_root():
    return {"Hello": "World"}
'''

with open('main.py', 'w') as file:
    file.write(main_file)

# %% [markdown]
# Запустим http-сервер **uvicorn** с указанием приложения, которое будет запускаться (**app** из файла **main.py**):

# %%
# !nohup uvicorn main:app --reload &
# nohup и & - прописываются для запуска процесса в фоне (чтобы не блокировать Colab)
# параметр --reload позволяет автоматически перезапускать uvicorn при изменениях в файле main.py
# Out:
# nohup: appending output to 'nohup.out'

# %% [markdown]
# Логи http-сервера теперь выводятся в файл **nohup.out**:

# %%
# !cat nohup.out
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [1450] using StatReload
# INFO:     Started server process [1452]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.

# %% [markdown]
# Сделаем пробный запрос к созданнму эндпойнту (одному из адресов для запросов через API):

# %%
import requests

# %%
r = requests.get('http://127.0.0.1:8000/test')
print(r.status_code)
print(r.text)
# Out:
# 200
# {"Hello":"World"}

# %% [markdown]
# При возникновении ошибки просто перезапустите ячейку.

# %% [markdown]
# Создадим новый эндпойнт, который будет принимать файл с изображением и возвращать результат:

# %%
main_file = '''from fastapi import FastAPI, File
from predict import process

app = FastAPI()


@app.post("/predict")
async def create_file(file: bytes = File(...)):
    return {"result": process(file)}
'''

with open('main.py', 'w') as file:
    file.write(main_file)

# %% [markdown]
# Отправим изображение на эндпойнт для классификации:

# %%
# Загрузка тестового изображения:
gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l16/auto.jpg', None, quiet=True)
# Out:
# 'auto.jpg'

# %%
files = {'file': open('auto.jpg','rb')}
r = requests.post('http://127.0.0.1:8000/predict', files=files)
print(r.text)
# Out:
# {"result":"[np.float32(0.0), np.float32(1.0), np.float32(0.0)]"}

# %% [markdown]
# Проверим текст ответа на запрос (мы должны получить вероятности принадлежности изображения к каждому из трех классов):

# %%
class_names = ['Ferrari', 'Mercedes', 'Renault']

# %%
import matplotlib.pyplot as plt
from PIL import Image

plt.imshow(Image.open('auto.jpg'))
plt.show()

# %% [markdown]
# Создадим файл зависимостей. В нем перечисляются требуемые пакеты **Python** и их версии:

# %%
requirements_file = '''

fastapi==0.68.1
tensorflow-cpu==2.8.0
uvicorn==0.15.0
Pillow==7.1.2
python-multipart==0.0.5
protobuf<=3.20.1
'''

with open('requirements.txt', 'w') as file:
    file.write(requirements_file)

# %% [markdown]
# Удалим лишние файлы, по умолчанию находящиеся в текущей папке Colab:

# %%
# !rm -rf sample_data

# %% [markdown]
# # 3. Деплой (развертывание) сервиса на бесплатный хостинг

# %% [markdown]
# Используем сервис **Amvera** так же, как в предыдущем занятии:
#
# [Создание простого веб-сервера и настройка параметров работы
# ](https://colab.research.google.com/drive/1qo9-lQFa4VTeALAwbRux6bfuxuEiL26o?usp=sharing)

# %% [markdown]
# ## Регистрация аккаунта в Amvera

# %% [markdown]
# Пройдите регистрацию аккаунта Amvera на данной [странице](https://amvera.ru/cloud).<br>
# Этот шаг можно пропустить, если у вас уже есть аккаунт.
#
# Каждому пользователю при регистрации начисляется 1000 руб. на счет по умолчанию. Этого хватит примерно на 3 месяца бесплатного использования.

# %% [markdown]
# ---
# **Условия для студентов УИИ** при регистрации в Amvera:
#
# *   промокод **StudentUAI** действует с 1 июля 2023 и начисляет дополнительно 300 руб. на баланс;
# *   чтобы баланса хватило на весь курс, не забывайте останавливать проект, когда его работа не требуется, уменьшая количество требуемых инстансов (экземпляров серверных ресурсов) до нуля в личном кабинете. Тарификация производится поминутно, и при количестве инстансов, равном нулю, баланс списываться не будет.
# ---

# %% [markdown]
# ![00.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![01.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Для завершения регистрации следует подтвердить свой адрес электронной почты.

# %% [markdown]
# ## Установка и настройка **Git**

# %% [markdown]
# Шаг с установкой **Git** можно пропустить, так как виртуальные машины Google Colab уже содержат предустановленный пакет **Git**.
#
# Проверим наличие и версию **Git**:

# %%
# !git --version
# Out:
# git version 2.25.1

# %% [markdown]
# Зададим имя пользователя и e-mail для **Git**. Укажите свой email и имя пользователя, введенные при регистрации в Amvera:

# %%
# Укажите свои данные
# !git config --global user.email "your@email.com"
# !git config --global user.name "username"

# %% [markdown]
# Создадим файл конфигурации **amvera.yml** и добавим в него команду запуска нашего сервиса `uvicorn main:app --host=0.0.0.0 --port=${PORT:-5000}`:

# %%
amvera_yml = '''
meta:
  environment: python
  toolchain:
    name: pip
    version: 3.10.12
build:
  requirementsPath: requirements.txt
run:
  command: uvicorn main:app --host=0.0.0.0 --port=${PORT:-5000}
  persistenceMount: /data
  containerPort: 80
'''

with open('amvera.yml', 'w') as file:
    file.write(amvera_yml)

# %% [markdown]
# ## Создание удаленного репозитория в **Amvera**

# %% [markdown]
# Создадим проект в Amvera. Откройте страницу с проектами https://cloud.amvera.ru/projects и нажмите кнопку "Создать". Укажите параметры как на изображении:

# %% [markdown]
# ![01.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Перейдите на страницу созданного проекта. На ней вы увидите ссылку на созданный удаленный репозиторий.![02.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Git remotes - это версии вашего репозитория, которые находятся на других серверах. Вы развертываете свое приложение, отправляя его код на специальный удаленный сервер **Amvera**, связанный с вашим приложением.

# %% [markdown]
# Создадим переменные для часто используемых данных. Укажите свои имя пользователя и пароль. В переменную `repo` запишем название созданного репозитория в **Amvera** под проект "Cars".

# %%
USER = "username"
PASSWORD = input('Введите пароль для Amvera:')
repo = "cars"

# %% [markdown]
# Склонируем пустой репозиторий из **Amvera** в **Google Colab**:

# %%
# !git clone https://{USER}:{PASSWORD}@git.amvera.ru/{USER}/{repo}
# Out:
# Cloning into 'cars'...
# warning: You appear to have cloned an empty repository.

# %% [markdown]
# Переместим в локальный репозиторий наши файлы:

# %%
# !mv main.py cars3.h5 requirements.txt predict.py amvera.yml auto.jpg nohup.out /content/{repo}

# %% [markdown]
# Перейдем в директорию локального репозитория:

# %%
# %cd {repo}
# Out:
# /content/cars

# %% [markdown]
# Для того, чтобы разорвать текущее соединение с удаленным репоизорием используйте команду:
#
#         !git remote rm origin

# %% [markdown]
# ## Отслеживание проекта в **Git**

# %% [markdown]
# Прежде чем вы сможете развернуть свое приложение в **Amvera**, вам необходимо инициализировать локальный репозиторий **Git** и зафиксировать в нем код вашего приложения:

# %%
# !git init
# !git add .
# !git commit -m "My first commit"
# Out:
# Reinitialized existing Git repository in /content/cars/.git/
# [master (root-commit) 0b32bfb] My first commit
#  7 files changed, 77 insertions(+)
#  create mode 100644 amvera.yml
#  create mode 100644 auto.jpg
#  create mode 100644 cars3.h5
#  create mode 100644 main.py
#  create mode 100644 nohup.out
#  create mode 100644 predict.py
#  create mode 100644 requirements.txt

# %% [markdown]
# Код приложения теперь отслеживается в локальном репозитории **Git**. Он еще не отправлен на удаленный сервер.

# %% [markdown]
# ## Развертывание кода

# %% [markdown]
# Для развертывания приложения в **Amvera** нужно использовать команду `git push`, чтобы отправить код из главной или основной ветки локального репозитория на удаленный сервер **origin**:

# %%
# !git push -u origin master
# Out:
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 897.23 KiB | 11.96 MiB/s, done.
# Total 9 (delta 0), reused 0 (delta 0)
# remote: Updating references: 100% (1/1)
# remote: Detected changes in master branch, deploying
# To https://git.amvera.ru/anjela/cars
#  * [new branch]      master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %% [markdown]
# Используйте эту же команду всякий раз, когда хотите развернуть последнюю зафиксированную версию вашего кода в **Amvera**.
#
# Обратите внимание, что **Amvera** развертывает только тот код, который вы отправляете в ветку **master** или **main**. Перенос кода в другую ветку удаленного репозитория **Amvera** не даст никакого эффекта.

# %% [markdown]
# ## Проверка результата

# %% [markdown]
# Дождитесь статуса "Успешно развернуто"

# %% [markdown]
# Отправим запрос с изображением на удаленный сервер. Укажем в запросе URL, полученный при создании проекта в **Amvera**:

# %%
files = {'file': open('auto.jpg','rb')}
r = requests.post('https://cars-serg88.amvera.io/predict', files=files)
print(r.status_code)
# Out:
# 200

# %% [markdown]
# Проверим результат предсказания:

# %%
r.json()
# Out:
# {'result': '[0.0, 1.0, 0.0]'}

# %% [markdown]
# Поздравляем!
# Вы создали веб-сервис с собственным API и разместили его в интернете!
